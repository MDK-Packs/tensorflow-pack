# %% [markdown]
# # Train a Simple TensorFlow Lite for Microcontrollers model (Preview)
#
#
# ## Introduction to the Jupyter Notebook
#
# This Jupyter Notebook is inspired by the **Hello World Example** from the official LiteRT documentation for microcontrollers, which demonstrates how to train and deploy a model to predict the sine of a given input value [LiteRT Documentation](https://ai.google.dev/edge/litert/microcontrollers/get_started). The models trained here will be deployed directly to the model layer of this project.
#
# #### Project Overview
#
# The complete project is a hardware-agnostic [CMSIS Reference Application](https://github.com/Open-CMSIS-Pack/cmsis-toolbox/blob/main/docs/ReferenceApplications.md), designed to be compatible with any target hardware that supports the STDIO feature. This flexibility allows users to adapt the application to various devices without significant modifications.
#
# #### Deep Learning and Sine Function Modeling
#
# Deep learning networks are powerful tools for modeling patterns in data. In this notebook, we focus on training a network to model data generated by a **sine function**. The goal is to create a model that can take an input value `x` and predict its sine, `y`. This process involves training the model using a dataset of sine values and then deploying it for inference.
#
# #### Training Process
#
# The training process for the official model is outlined in the **`train.py`** script, which is part of the TensorFlow Lite Micro examples. This notebook picks up parts of it to train two models in a step by step approach.
#
# #### Notebook Structure
#
# This notebook will guide you through the following steps:
#
# **Data Generation**: Creating a dataset of sine values.
#
# **Model Training**: Training a neural network to predict sine values.
#
# **Model Deployment**: Deploying the trained model to the project's model layer.
#
# By following these steps, you will learn how to develop and deploy a simple deep learning model using LiteRT for microcontrollers.

# %% [markdown]
# ### Install Python Packages required
#
# Run pip to install Tensorflow etc. into the current environment.

# %%
#Tested on Python 3.11.5
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: tensorflow==2.17.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (2.17.0)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (3.10.1)
# Requirement already satisfied: ethos_u_vela in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (4.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (3.13.0)
# Requirement already satisfied: libclang>=13.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: packaging in /Users/mather01/Library/Python/3.11/lib/python/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /Users/mather01/Library/Python/3.11/lib/python/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/mather01/Library/Python/3.11/lib/python/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (1.70.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (3.9.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.17.0->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mather01/Library/Python/3.11/lib/python/site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 2)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 2)) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 3)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 3)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 3)) (3.2.1)
# Requirement already satisfied: lxml>=4.5.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ethos_u_vela->-r requirements.txt (line 4)) (5.3.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (0.45.1)
# Requirement already satisfied: rich in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (13.9.4)
# Requirement already satisfied: namex in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (0.0.8)
# Requirement already satisfied: optree in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from keras>=3.2.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0->-r requirements.txt (line 1)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0->-r requirements.txt (line 1)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0->-r requirements.txt (line 1)) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow==2.17.0->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/mather01/Library/Python/3.11/lib/python/site-packages (from rich->keras>=3.2.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow==2.17.0->-r requirements.txt (line 1)) (0.1.2)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip

# %% [markdown]
# ### Configure Defaults
# Configure pathes and filenames for generated files.

# %%
# Define paths to model files
import os
MODELS_DIR = 'models/'
if not os.path.exists(MODELS_DIR):
    os.mkdir(MODELS_DIR)
MODEL_KERAS = MODELS_DIR + 'model.keras'
MODEL_NO_QUANT_TFLITE = MODELS_DIR + 'model_float.tflite'
MODEL_INT8_QUANT_TFLITE = MODELS_DIR + 'model_int8.tflite'
MODEL_NO_QUANT_C = MODELS_DIR + 'model_float.c'
MODEL_INT8_QUANT_C = MODELS_DIR + 'model_int8.c'

# %% [markdown]
# ### Check Environment
#
# This script prints out key information about the environment, including:
#
# - **Python Platform**: The underlying platform (e.g., Windows, Linux).
# - **Python Version**: The version of Python being used.
# - **TensorFlow, Keras, and Pandas Versions**: The versions of these libraries installed.
# - **GPU Availability**: Whether a GPU is available for use with TensorFlow.

# %%
import sys
import keras
import pandas as pd
import tensorflow as tf
import platform
print(f"Python Platform: {platform.platform()}")
print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Python Platform: macOS-15.3.2-arm64-arm-64bit
# Tensor Flow Version: 2.17.0
# Keras Version: 3.9.0
#
# Python 3.11.9 (v3.11.9:de54cf5be3, Apr  2 2024, 07:12:50) [Clang 13.0.0 (clang-1300.0.29.30)]
# Pandas 2.2.3
# GPU is NOT AVAILABLE

# %% [markdown]
# ### Import Additional Dependencies

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# Set seed for experiment reproducibility
seed = 1
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Generate Data
#
# The code in the following cell will generate a set of random `x` values, calculate their sine values, and display them on a graph.

# %%
# Number of sample datapoints
SAMPLES = 1000

# Generate a uniformly distributed set of random numbers in the range from
# 0 to 2π, which covers a complete sine wave oscillation
x_values = np.random.uniform(
    low=0, high=2*math.pi, size=SAMPLES).astype(np.float32)

# Shuffle the values to guarantee they're not in order
np.random.shuffle(x_values)

x_values.shape, x_values.min(), x_values.max()
x_values[:10]

# Calculate the corresponding sine values
y_values = np.sin(x_values).astype(np.float32)

# Plot our data. The 'b.' argument tells the library to print blue dots.
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ### Add Noise
# Since it was generated directly by the sine function, our data fits a nice, smooth curve.
#
# However, machine learning models are good at extracting underlying meaning from messy, real world data. To demonstrate this, we can add some noise to our data to approximate something more life-like.
#
# In the following cell, we'll add some random noise to each value, then draw a new graph:

# %%
# Add a small random number to each y value
y_values += 0.1 * np.random.randn(*y_values.shape)

# Plot our data
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ### 3. Split the Data
# We now have a noisy dataset that approximates real world data. We'll be using this to train our model.
#
# To evaluate the accuracy of the model we train, we'll need to compare its predictions to real data and check how well they match up. This evaluation happens during training (where it is referred to as validation) and after training (referred to as testing) It's important in both cases that we use fresh data that was not already used to train the model.
#
# The data is split as follows:
#   1. Training: 60%
#   2. Validation: 20%
#   3. Testing: 20%
#
# The following code will split our data and then plots each set as a different color:

# %%
# We'll use 60% of our data for training and 20% for testing. The remaining 20%
# will be used for validation. Calculate the indices of each section.
TRAIN_SPLIT =  int(0.6 * SAMPLES)
TEST_SPLIT = int(0.2 * SAMPLES + TRAIN_SPLIT)
TRAIN_SPLIT, TEST_SPLIT


# Use np.split to chop our data into three parts.
# The second argument to np.split is an array of indices where the data will be
# split. We provide two indices, so the data will be divided into three chunks.
x_train, x_test, x_validate = np.split(x_values, [TRAIN_SPLIT, TEST_SPLIT])
y_train, y_test, y_validate = np.split(y_values, [TRAIN_SPLIT, TEST_SPLIT])

# Double check that our splits add up correctly
assert (x_train.size + x_validate.size + x_test.size) ==  SAMPLES
x_train.shape, x_test.shape, x_validate.shape


# Plot the data in each partition in different colors:
plt.plot(x_train, y_train, 'b.', label="Train")
plt.plot(x_test, y_test, 'r.', label="Test")
plt.plot(x_validate, y_validate, 'y.', label="Validate")
plt.legend()
plt.show()

# %% [markdown]
# ## Training a Simple Model

# %% [markdown]
# ### Design the Model
# We're going to build a simple neural network model that will take an input value (in this case, `x`) and use it to predict a numeric output value (the sine of `x`). This type of problem is called a _regression_. It will use _layers_ of _neurons_ to attempt to learn any patterns underlying the training data, so it can make predictions.
#
# To begin with, we'll define two layers. The first layer takes a single input (our `x` value) and runs it through 8 neurons. Based on this input, each neuron will become _activated_ to a certain degree based on its internal state (its _weight_ and _bias_ values). A neuron's degree of activation is expressed as a number.
#
# The activation numbers from our first layer will be fed as inputs to our second layer, which is a single neuron. It will apply its own weights and bias to these inputs and calculate its own activation, which will be output as our `y` value.
#
# **Note:** To learn more about how neural networks function, you can explore the [Learn TensorFlow](https://codelabs.developers.google.com/codelabs/tensorflow-lab1-helloworld) codelabs.
#
# The code in the following cell defines our model using [Keras](https://www.tensorflow.org/guide/keras), TensorFlow's high-level API for creating deep learning networks. Once the network is defined, we _compile_ it, specifying parameters that determine how it will be trained:

# %%
# Create model with proper input definition
model_small = keras.Sequential([
    keras.layers.Input(shape=(1,)),             # Explicit input layer for scalar input
    keras.layers.Dense(8, activation='relu'),    # Hidden layer with 8 neurons and ReLU
    keras.layers.Dense(1)                        # Output layer with single neuron
])

# Compile model with same optimization settings
model_small.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Display model architecture
model_small.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25 (100.00 B)
#  Trainable params: 25 (100.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train the Model
# Once we've defined the model, we can use our data to _train_ it. Training involves passing an `x` value into the neural network, checking how far the network's output deviates from the expected `y` value, and adjusting the neurons' weights and biases so that the output is more likely to be correct the next time.
#
# Training runs this process on the full dataset multiple times, and each full run-through is known as an _epoch_. The number of epochs to run during training is a parameter we can set.
#
# During each epoch, data is run through the network in multiple _batches_. Each batch, several pieces of data are passed into the network, producing output values. These outputs' correctness is measured in aggregate and the network's weights and biases are adjusted accordingly, once per batch. The _batch size_ is also a parameter we can set.
#
# The code in the following cell uses the `x` and `y` values from our training data to train the model. It runs for 500 _epochs_, with 64 pieces of data in each _batch_. We also pass in some data for _validation_. As you will see when you run the cell, training can take a while to complete:

# %%
# Train the model on our training data while validating on our validation set
history_small = model_small.fit(
    x_train,
    y_train,
    epochs=500,
    batch_size=64,
    validation_data=(x_validate, y_validate))
# Out:
# Epoch 1/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0154 - mae: 1.1539 - val_loss: 1.7226 - val_mae: 1.1083
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5731 - mae: 1.0458 - val_loss: 1.3438 - val_mae: 1.0071
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2246 - mae: 0.9488 - val_loss: 1.0585 - val_mae: 0.9186
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9672 - mae: 0.8677 - val_loss: 0.8576 - val_mae: 0.8443
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7896 - mae: 0.7987 - val_loss: 0.7249 - val_mae: 0.7833
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6748 - mae: 0.7432 - val_loss: 0.6421 - val_mae: 0.7334
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6047 - mae: 0.7032 - val_loss: 0.5921 - val_mae: 0.6941
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5631 - mae: 0.6733 - val_loss: 0.5616 - val_mae: 0.6667
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5377 - mae: 0.6524 - val_loss: 0.5415 - val_mae: 0.6473
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5207 - mae: 0.6367 - val_loss: 0.5265 - val_mae: 0.6330
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5074 - mae: 0.6244 - val_loss: 0.5137 - val_mae: 0.6229
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4956 - mae: 0.6145 - val_loss: 0.5020 - val_mae: 0.6150
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4845 - mae: 0.6062 - val_loss: 0.4907 - val_mae: 0.6078
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4737 - mae: 0.5983 - val_loss: 0.4798 - val_mae: 0.6009
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4630 - mae: 0.5908 - val_loss: 0.4691 - val_mae: 0.5941
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4526 - mae: 0.5836 - val_loss: 0.4586 - val_mae: 0.5874
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4424 - mae: 0.5764 - val_loss: 0.4483 - val_mae: 0.5809
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4324 - mae: 0.5693 - val_loss: 0.4382 - val_mae: 0.5744
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4226 - mae: 0.5622 - val_loss: 0.4283 - val_mae: 0.5680
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4131 - mae: 0.5554 - val_loss: 0.4188 - val_mae: 0.5617
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4038 - mae: 0.5487 - val_loss: 0.4094 - val_mae: 0.5556
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3948 - mae: 0.5421 - val_loss: 0.4004 - val_mae: 0.5497
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3861 - mae: 0.5357 - val_loss: 0.3916 - val_mae: 0.5439
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3776 - mae: 0.5296 - val_loss: 0.3831 - val_mae: 0.5382
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3694 - mae: 0.5235 - val_loss: 0.3748 - val_mae: 0.5328
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3615 - mae: 0.5176 - val_loss: 0.3668 - val_mae: 0.5274
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3538 - mae: 0.5118 - val_loss: 0.3591 - val_mae: 0.5220
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3464 - mae: 0.5062 - val_loss: 0.3517 - val_mae: 0.5168
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3392 - mae: 0.5007 - val_loss: 0.3445 - val_mae: 0.5119
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3322 - mae: 0.4954 - val_loss: 0.3375 - val_mae: 0.5071
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3255 - mae: 0.4903 - val_loss: 0.3308 - val_mae: 0.5024
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3190 - mae: 0.4853 - val_loss: 0.3243 - val_mae: 0.4978
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3127 - mae: 0.4805 - val_loss: 0.3181 - val_mae: 0.4934
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3067 - mae: 0.4759 - val_loss: 0.3121 - val_mae: 0.4893
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3009 - mae: 0.4714 - val_loss: 0.3063 - val_mae: 0.4853
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2952 - mae: 0.4671 - val_loss: 0.3007 - val_mae: 0.4814
# Epoch 37/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2898 - mae: 0.4630 - val_loss: 0.2954 - val_mae: 0.4775
# Epoch 38/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2846 - mae: 0.4589 - val_loss: 0.2903 - val_mae: 0.4737
# Epoch 39/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2796 - mae: 0.4550 - val_loss: 0.2853 - val_mae: 0.4700
# Epoch 40/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2747 - mae: 0.4511 - val_loss: 0.2806 - val_mae: 0.4664
# Epoch 41/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2701 - mae: 0.4473 - val_loss: 0.2760 - val_mae: 0.4629
# Epoch 42/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2656 - mae: 0.4436 - val_loss: 0.2717 - val_mae: 0.4594
# Epoch 43/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2614 - mae: 0.4401 - val_loss: 0.2675 - val_mae: 0.4562
# Epoch 44/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2573 - mae: 0.4367 - val_loss: 0.2635 - val_mae: 0.4531
# Epoch 45/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2533 - mae: 0.4335 - val_loss: 0.2596 - val_mae: 0.4501
# Epoch 46/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2495 - mae: 0.4305 - val_loss: 0.2560 - val_mae: 0.4473
# Epoch 47/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2459 - mae: 0.4276 - val_loss: 0.2524 - val_mae: 0.4446
# Epoch 48/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2424 - mae: 0.4248 - val_loss: 0.2491 - val_mae: 0.4419
# Epoch 49/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2391 - mae: 0.4222 - val_loss: 0.2458 - val_mae: 0.4393
# Epoch 50/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2359 - mae: 0.4197 - val_loss: 0.2428 - val_mae: 0.4369
# Epoch 51/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2329 - mae: 0.4173 - val_loss: 0.2398 - val_mae: 0.4346
# Epoch 52/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2300 - mae: 0.4150 - val_loss: 0.2370 - val_mae: 0.4324
# Epoch 53/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2272 - mae: 0.4127 - val_loss: 0.2343 - val_mae: 0.4303
# Epoch 54/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2245 - mae: 0.4106 - val_loss: 0.2318 - val_mae: 0.4282
# Epoch 55/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2220 - mae: 0.4085 - val_loss: 0.2293 - val_mae: 0.4261
# Epoch 56/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2196 - mae: 0.4064 - val_loss: 0.2270 - val_mae: 0.4240
# Epoch 57/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2172 - mae: 0.4044 - val_loss: 0.2248 - val_mae: 0.4221
# Epoch 58/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2150 - mae: 0.4025 - val_loss: 0.2227 - val_mae: 0.4202
# Epoch 59/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2129 - mae: 0.4006 - val_loss: 0.2207 - val_mae: 0.4184
# Epoch 60/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2109 - mae: 0.3989 - val_loss: 0.2187 - val_mae: 0.4168
# Epoch 61/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2090 - mae: 0.3972 - val_loss: 0.2169 - val_mae: 0.4153
# Epoch 62/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2071 - mae: 0.3955 - val_loss: 0.2152 - val_mae: 0.4139
# Epoch 63/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2054 - mae: 0.3939 - val_loss: 0.2135 - val_mae: 0.4125
# Epoch 64/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2037 - mae: 0.3924 - val_loss: 0.2119 - val_mae: 0.4112
# Epoch 65/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2021 - mae: 0.3909 - val_loss: 0.2104 - val_mae: 0.4098
# Epoch 66/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2005 - mae: 0.3895 - val_loss: 0.2089 - val_mae: 0.4085
# Epoch 67/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1991 - mae: 0.3881 - val_loss: 0.2075 - val_mae: 0.4072
# Epoch 68/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1977 - mae: 0.3868 - val_loss: 0.2062 - val_mae: 0.4059
# Epoch 69/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1963 - mae: 0.3855 - val_loss: 0.2049 - val_mae: 0.4047
# Epoch 70/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1951 - mae: 0.3842 - val_loss: 0.2037 - val_mae: 0.4034
# Epoch 71/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1939 - mae: 0.3830 - val_loss: 0.2026 - val_mae: 0.4022
# Epoch 72/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1927 - mae: 0.3818 - val_loss: 0.2015 - val_mae: 0.4010
# Epoch 73/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1916 - mae: 0.3807 - val_loss: 0.2005 - val_mae: 0.3998
# Epoch 74/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1906 - mae: 0.3796 - val_loss: 0.1995 - val_mae: 0.3987
# Epoch 75/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1896 - mae: 0.3786 - val_loss: 0.1985 - val_mae: 0.3975
# Epoch 76/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1886 - mae: 0.3776 - val_loss: 0.1976 - val_mae: 0.3964
# Epoch 77/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1877 - mae: 0.3766 - val_loss: 0.1968 - val_mae: 0.3953
# Epoch 78/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1868 - mae: 0.3757 - val_loss: 0.1959 - val_mae: 0.3942
# Epoch 79/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1860 - mae: 0.3748 - val_loss: 0.1951 - val_mae: 0.3931
# Epoch 80/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1851 - mae: 0.3739 - val_loss: 0.1944 - val_mae: 0.3921
# Epoch 81/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1844 - mae: 0.3730 - val_loss: 0.1937 - val_mae: 0.3912
# Epoch 82/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1836 - mae: 0.3722 - val_loss: 0.1930 - val_mae: 0.3902
# Epoch 83/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1829 - mae: 0.3714 - val_loss: 0.1923 - val_mae: 0.3893
# Epoch 84/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1822 - mae: 0.3706 - val_loss: 0.1917 - val_mae: 0.3884
# Epoch 85/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1815 - mae: 0.3698 - val_loss: 0.1911 - val_mae: 0.3875
# Epoch 86/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1809 - mae: 0.3691 - val_loss: 0.1905 - val_mae: 0.3866
# Epoch 87/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1802 - mae: 0.3683 - val_loss: 0.1899 - val_mae: 0.3858
# Epoch 88/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1796 - mae: 0.3676 - val_loss: 0.1894 - val_mae: 0.3849
# Epoch 89/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1791 - mae: 0.3669 - val_loss: 0.1889 - val_mae: 0.3841
# Epoch 90/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1785 - mae: 0.3662 - val_loss: 0.1884 - val_mae: 0.3833
# Epoch 91/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1780 - mae: 0.3655 - val_loss: 0.1879 - val_mae: 0.3825
# Epoch 92/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1775 - mae: 0.3648 - val_loss: 0.1875 - val_mae: 0.3818
# Epoch 93/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1770 - mae: 0.3642 - val_loss: 0.1870 - val_mae: 0.3810
# Epoch 94/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1765 - mae: 0.3635 - val_loss: 0.1866 - val_mae: 0.3803
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1760 - mae: 0.3629 - val_loss: 0.1862 - val_mae: 0.3795
# Epoch 96/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1755 - mae: 0.3623 - val_loss: 0.1858 - val_mae: 0.3788
# Epoch 97/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1751 - mae: 0.3616 - val_loss: 0.1854 - val_mae: 0.3781
# Epoch 98/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1746 - mae: 0.3610 - val_loss: 0.1850 - val_mae: 0.3773
# Epoch 99/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1742 - mae: 0.3604 - val_loss: 0.1847 - val_mae: 0.3766
# Epoch 100/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1738 - mae: 0.3598 - val_loss: 0.1843 - val_mae: 0.3759
# Epoch 101/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1734 - mae: 0.3593 - val_loss: 0.1840 - val_mae: 0.3752
# Epoch 102/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1730 - mae: 0.3587 - val_loss: 0.1836 - val_mae: 0.3746
# Epoch 103/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1726 - mae: 0.3582 - val_loss: 0.1833 - val_mae: 0.3740
# Epoch 104/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1722 - mae: 0.3576 - val_loss: 0.1830 - val_mae: 0.3734
# Epoch 105/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1719 - mae: 0.3571 - val_loss: 0.1827 - val_mae: 0.3728
# Epoch 106/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1715 - mae: 0.3565 - val_loss: 0.1824 - val_mae: 0.3723
# Epoch 107/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1711 - mae: 0.3560 - val_loss: 0.1821 - val_mae: 0.3717
# Epoch 108/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1708 - mae: 0.3555 - val_loss: 0.1818 - val_mae: 0.3711
# Epoch 109/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1705 - mae: 0.3550 - val_loss: 0.1816 - val_mae: 0.3706
# Epoch 110/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1701 - mae: 0.3545 - val_loss: 0.1813 - val_mae: 0.3700
# Epoch 111/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1698 - mae: 0.3540 - val_loss: 0.1810 - val_mae: 0.3695
# Epoch 112/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1695 - mae: 0.3535 - val_loss: 0.1808 - val_mae: 0.3689
# Epoch 113/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1692 - mae: 0.3530 - val_loss: 0.1805 - val_mae: 0.3684
# Epoch 114/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1689 - mae: 0.3525 - val_loss: 0.1803 - val_mae: 0.3679
# Epoch 115/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1686 - mae: 0.3521 - val_loss: 0.1800 - val_mae: 0.3674
# Epoch 116/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1683 - mae: 0.3516 - val_loss: 0.1798 - val_mae: 0.3669
# Epoch 117/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1680 - mae: 0.3511 - val_loss: 0.1796 - val_mae: 0.3665
# Epoch 118/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1677 - mae: 0.3507 - val_loss: 0.1794 - val_mae: 0.3660
# Epoch 119/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1674 - mae: 0.3502 - val_loss: 0.1791 - val_mae: 0.3655
# Epoch 120/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1672 - mae: 0.3498 - val_loss: 0.1789 - val_mae: 0.3651
# Epoch 121/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1669 - mae: 0.3493 - val_loss: 0.1787 - val_mae: 0.3646
# Epoch 122/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1666 - mae: 0.3489 - val_loss: 0.1785 - val_mae: 0.3642
# Epoch 123/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1663 - mae: 0.3485 - val_loss: 0.1783 - val_mae: 0.3637
# Epoch 124/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1661 - mae: 0.3480 - val_loss: 0.1781 - val_mae: 0.3633
# Epoch 125/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1658 - mae: 0.3476 - val_loss: 0.1779 - val_mae: 0.3629
# Epoch 126/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1655 - mae: 0.3472 - val_loss: 0.1777 - val_mae: 0.3625
# Epoch 127/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1653 - mae: 0.3468 - val_loss: 0.1775 - val_mae: 0.3621
# Epoch 128/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1650 - mae: 0.3463 - val_loss: 0.1773 - val_mae: 0.3617
# Epoch 129/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1648 - mae: 0.3459 - val_loss: 0.1771 - val_mae: 0.3613
# Epoch 130/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1645 - mae: 0.3455 - val_loss: 0.1769 - val_mae: 0.3609
# Epoch 131/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1643 - mae: 0.3451 - val_loss: 0.1767 - val_mae: 0.3605
# Epoch 132/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1641 - mae: 0.3447 - val_loss: 0.1766 - val_mae: 0.3601
# Epoch 133/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1638 - mae: 0.3443 - val_loss: 0.1764 - val_mae: 0.3597
# Epoch 134/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1636 - mae: 0.3439 - val_loss: 0.1762 - val_mae: 0.3594
# Epoch 135/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1634 - mae: 0.3435 - val_loss: 0.1761 - val_mae: 0.3590
# Epoch 136/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1631 - mae: 0.3432 - val_loss: 0.1759 - val_mae: 0.3586
# Epoch 137/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1629 - mae: 0.3428 - val_loss: 0.1757 - val_mae: 0.3583
# Epoch 138/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1627 - mae: 0.3424 - val_loss: 0.1756 - val_mae: 0.3579
# Epoch 139/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1625 - mae: 0.3420 - val_loss: 0.1754 - val_mae: 0.3575
# Epoch 140/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1623 - mae: 0.3416 - val_loss: 0.1753 - val_mae: 0.3572
# Epoch 141/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1621 - mae: 0.3412 - val_loss: 0.1751 - val_mae: 0.3568
# Epoch 142/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1618 - mae: 0.3409 - val_loss: 0.1750 - val_mae: 0.3565
# Epoch 143/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1616 - mae: 0.3405 - val_loss: 0.1748 - val_mae: 0.3562
# Epoch 144/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1614 - mae: 0.3401 - val_loss: 0.1747 - val_mae: 0.3558
# Epoch 145/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1612 - mae: 0.3397 - val_loss: 0.1745 - val_mae: 0.3555
# Epoch 146/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1610 - mae: 0.3394 - val_loss: 0.1744 - val_mae: 0.3552
# Epoch 147/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1608 - mae: 0.3390 - val_loss: 0.1742 - val_mae: 0.3549
# Epoch 148/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1607 - mae: 0.3387 - val_loss: 0.1741 - val_mae: 0.3546
# Epoch 149/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1605 - mae: 0.3384 - val_loss: 0.1740 - val_mae: 0.3543
# Epoch 150/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1603 - mae: 0.3380 - val_loss: 0.1738 - val_mae: 0.3540
# Epoch 151/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1601 - mae: 0.3377 - val_loss: 0.1737 - val_mae: 0.3537
# Epoch 152/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1599 - mae: 0.3374 - val_loss: 0.1736 - val_mae: 0.3534
# Epoch 153/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1598 - mae: 0.3371 - val_loss: 0.1735 - val_mae: 0.3531
# Epoch 154/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1596 - mae: 0.3368 - val_loss: 0.1733 - val_mae: 0.3528
# Epoch 155/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1594 - mae: 0.3365 - val_loss: 0.1732 - val_mae: 0.3525
# Epoch 156/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1593 - mae: 0.3362 - val_loss: 0.1731 - val_mae: 0.3522
# Epoch 157/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1591 - mae: 0.3359 - val_loss: 0.1730 - val_mae: 0.3519
# Epoch 158/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1589 - mae: 0.3356 - val_loss: 0.1728 - val_mae: 0.3516
# Epoch 159/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1588 - mae: 0.3353 - val_loss: 0.1727 - val_mae: 0.3513
# Epoch 160/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1586 - mae: 0.3350 - val_loss: 0.1726 - val_mae: 0.3510
# Epoch 161/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1585 - mae: 0.3347 - val_loss: 0.1725 - val_mae: 0.3507
# Epoch 162/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1583 - mae: 0.3344 - val_loss: 0.1724 - val_mae: 0.3505
# Epoch 163/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1582 - mae: 0.3341 - val_loss: 0.1723 - val_mae: 0.3502
# Epoch 164/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1580 - mae: 0.3338 - val_loss: 0.1722 - val_mae: 0.3499
# Epoch 165/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1579 - mae: 0.3335 - val_loss: 0.1720 - val_mae: 0.3496
# Epoch 166/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1577 - mae: 0.3332 - val_loss: 0.1719 - val_mae: 0.3493
# Epoch 167/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1576 - mae: 0.3329 - val_loss: 0.1718 - val_mae: 0.3491
# Epoch 168/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1574 - mae: 0.3325 - val_loss: 0.1717 - val_mae: 0.3488
# Epoch 169/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1573 - mae: 0.3322 - val_loss: 0.1716 - val_mae: 0.3485
# Epoch 170/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1571 - mae: 0.3319 - val_loss: 0.1715 - val_mae: 0.3482
# Epoch 171/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1570 - mae: 0.3316 - val_loss: 0.1714 - val_mae: 0.3480
# Epoch 172/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1568 - mae: 0.3314 - val_loss: 0.1713 - val_mae: 0.3477
# Epoch 173/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1567 - mae: 0.3311 - val_loss: 0.1712 - val_mae: 0.3474
# Epoch 174/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1566 - mae: 0.3308 - val_loss: 0.1711 - val_mae: 0.3471
# Epoch 175/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1564 - mae: 0.3305 - val_loss: 0.1710 - val_mae: 0.3469
# Epoch 176/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1563 - mae: 0.3302 - val_loss: 0.1709 - val_mae: 0.3466
# Epoch 177/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1562 - mae: 0.3299 - val_loss: 0.1708 - val_mae: 0.3464
# Epoch 178/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1561 - mae: 0.3296 - val_loss: 0.1708 - val_mae: 0.3461
# Epoch 179/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1559 - mae: 0.3294 - val_loss: 0.1707 - val_mae: 0.3458
# Epoch 180/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1558 - mae: 0.3291 - val_loss: 0.1706 - val_mae: 0.3456
# Epoch 181/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1557 - mae: 0.3288 - val_loss: 0.1705 - val_mae: 0.3453
# Epoch 182/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1556 - mae: 0.3285 - val_loss: 0.1704 - val_mae: 0.3451
# Epoch 183/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1555 - mae: 0.3282 - val_loss: 0.1703 - val_mae: 0.3448
# Epoch 184/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1553 - mae: 0.3280 - val_loss: 0.1703 - val_mae: 0.3446
# Epoch 185/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1552 - mae: 0.3277 - val_loss: 0.1702 - val_mae: 0.3443
# Epoch 186/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1551 - mae: 0.3274 - val_loss: 0.1701 - val_mae: 0.3441
# Epoch 187/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1550 - mae: 0.3272 - val_loss: 0.1700 - val_mae: 0.3438
# Epoch 188/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1549 - mae: 0.3269 - val_loss: 0.1700 - val_mae: 0.3436
# Epoch 189/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1548 - mae: 0.3266 - val_loss: 0.1699 - val_mae: 0.3434
# Epoch 190/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1547 - mae: 0.3263 - val_loss: 0.1698 - val_mae: 0.3432
# Epoch 191/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1546 - mae: 0.3261 - val_loss: 0.1697 - val_mae: 0.3429
# Epoch 192/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1545 - mae: 0.3258 - val_loss: 0.1697 - val_mae: 0.3427
# Epoch 193/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1544 - mae: 0.3256 - val_loss: 0.1696 - val_mae: 0.3425
# Epoch 194/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1543 - mae: 0.3253 - val_loss: 0.1695 - val_mae: 0.3423
# Epoch 195/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1542 - mae: 0.3251 - val_loss: 0.1695 - val_mae: 0.3421
# Epoch 196/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1541 - mae: 0.3248 - val_loss: 0.1694 - val_mae: 0.3419
# Epoch 197/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1540 - mae: 0.3245 - val_loss: 0.1693 - val_mae: 0.3417
# Epoch 198/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1539 - mae: 0.3243 - val_loss: 0.1693 - val_mae: 0.3414
# Epoch 199/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1538 - mae: 0.3240 - val_loss: 0.1692 - val_mae: 0.3412
# Epoch 200/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1537 - mae: 0.3238 - val_loss: 0.1692 - val_mae: 0.3410
# Epoch 201/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1536 - mae: 0.3236 - val_loss: 0.1691 - val_mae: 0.3408
# Epoch 202/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1535 - mae: 0.3233 - val_loss: 0.1690 - val_mae: 0.3406
# Epoch 203/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1534 - mae: 0.3231 - val_loss: 0.1690 - val_mae: 0.3405
# Epoch 204/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1533 - mae: 0.3228 - val_loss: 0.1689 - val_mae: 0.3403
# Epoch 205/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1532 - mae: 0.3226 - val_loss: 0.1689 - val_mae: 0.3401
# Epoch 206/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1531 - mae: 0.3224 - val_loss: 0.1688 - val_mae: 0.3399
# Epoch 207/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1531 - mae: 0.3221 - val_loss: 0.1688 - val_mae: 0.3397
# Epoch 208/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1530 - mae: 0.3219 - val_loss: 0.1687 - val_mae: 0.3396
# Epoch 209/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1529 - mae: 0.3217 - val_loss: 0.1687 - val_mae: 0.3394
# Epoch 210/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1528 - mae: 0.3215 - val_loss: 0.1686 - val_mae: 0.3392
# Epoch 211/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1527 - mae: 0.3213 - val_loss: 0.1685 - val_mae: 0.3390
# Epoch 212/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1527 - mae: 0.3210 - val_loss: 0.1685 - val_mae: 0.3389
# Epoch 213/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1526 - mae: 0.3208 - val_loss: 0.1684 - val_mae: 0.3387
# Epoch 214/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1525 - mae: 0.3206 - val_loss: 0.1684 - val_mae: 0.3385
# Epoch 215/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1524 - mae: 0.3204 - val_loss: 0.1683 - val_mae: 0.3384
# Epoch 216/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1523 - mae: 0.3202 - val_loss: 0.1683 - val_mae: 0.3382
# Epoch 217/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1523 - mae: 0.3200 - val_loss: 0.1683 - val_mae: 0.3380
# Epoch 218/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1522 - mae: 0.3198 - val_loss: 0.1682 - val_mae: 0.3379
# Epoch 219/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1521 - mae: 0.3196 - val_loss: 0.1682 - val_mae: 0.3377
# Epoch 220/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1521 - mae: 0.3194 - val_loss: 0.1681 - val_mae: 0.3375
# Epoch 221/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1520 - mae: 0.3192 - val_loss: 0.1681 - val_mae: 0.3374
# Epoch 222/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1519 - mae: 0.3190 - val_loss: 0.1680 - val_mae: 0.3372
# Epoch 223/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1518 - mae: 0.3188 - val_loss: 0.1680 - val_mae: 0.3370
# Epoch 224/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1518 - mae: 0.3186 - val_loss: 0.1679 - val_mae: 0.3369
# Epoch 225/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1517 - mae: 0.3184 - val_loss: 0.1679 - val_mae: 0.3367
# Epoch 226/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1516 - mae: 0.3182 - val_loss: 0.1679 - val_mae: 0.3366
# Epoch 227/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1516 - mae: 0.3180 - val_loss: 0.1678 - val_mae: 0.3364
# Epoch 228/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1515 - mae: 0.3178 - val_loss: 0.1678 - val_mae: 0.3363
# Epoch 229/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1514 - mae: 0.3177 - val_loss: 0.1677 - val_mae: 0.3362
# Epoch 230/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1514 - mae: 0.3175 - val_loss: 0.1677 - val_mae: 0.3360
# Epoch 231/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1513 - mae: 0.3173 - val_loss: 0.1677 - val_mae: 0.3359
# Epoch 232/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1513 - mae: 0.3172 - val_loss: 0.1676 - val_mae: 0.3357
# Epoch 233/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1512 - mae: 0.3170 - val_loss: 0.1676 - val_mae: 0.3356
# Epoch 234/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1511 - mae: 0.3169 - val_loss: 0.1676 - val_mae: 0.3355
# Epoch 235/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1511 - mae: 0.3168 - val_loss: 0.1675 - val_mae: 0.3353
# Epoch 236/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1510 - mae: 0.3166 - val_loss: 0.1675 - val_mae: 0.3352
# Epoch 237/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1510 - mae: 0.3165 - val_loss: 0.1675 - val_mae: 0.3351
# Epoch 238/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1509 - mae: 0.3164 - val_loss: 0.1674 - val_mae: 0.3349
# Epoch 239/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1509 - mae: 0.3162 - val_loss: 0.1674 - val_mae: 0.3348
# Epoch 240/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1508 - mae: 0.3161 - val_loss: 0.1674 - val_mae: 0.3347
# Epoch 241/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1508 - mae: 0.3160 - val_loss: 0.1673 - val_mae: 0.3346
# Epoch 242/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1507 - mae: 0.3159 - val_loss: 0.1673 - val_mae: 0.3345
# Epoch 243/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1507 - mae: 0.3157 - val_loss: 0.1673 - val_mae: 0.3344
# Epoch 244/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1506 - mae: 0.3156 - val_loss: 0.1673 - val_mae: 0.3343
# Epoch 245/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1506 - mae: 0.3155 - val_loss: 0.1672 - val_mae: 0.3342
# Epoch 246/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1505 - mae: 0.3153 - val_loss: 0.1672 - val_mae: 0.3341
# Epoch 247/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1505 - mae: 0.3152 - val_loss: 0.1672 - val_mae: 0.3340
# Epoch 248/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1505 - mae: 0.3151 - val_loss: 0.1672 - val_mae: 0.3339
# Epoch 249/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1504 - mae: 0.3150 - val_loss: 0.1671 - val_mae: 0.3338
# Epoch 250/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1504 - mae: 0.3149 - val_loss: 0.1671 - val_mae: 0.3337
# Epoch 251/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1503 - mae: 0.3147 - val_loss: 0.1671 - val_mae: 0.3336
# Epoch 252/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1503 - mae: 0.3146 - val_loss: 0.1671 - val_mae: 0.3335
# Epoch 253/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1503 - mae: 0.3145 - val_loss: 0.1670 - val_mae: 0.3334
# Epoch 254/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1502 - mae: 0.3144 - val_loss: 0.1670 - val_mae: 0.3333
# Epoch 255/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1502 - mae: 0.3143 - val_loss: 0.1670 - val_mae: 0.3332
# Epoch 256/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1501 - mae: 0.3142 - val_loss: 0.1670 - val_mae: 0.3331
# Epoch 257/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1501 - mae: 0.3141 - val_loss: 0.1670 - val_mae: 0.3331
# Epoch 258/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1501 - mae: 0.3140 - val_loss: 0.1669 - val_mae: 0.3330
# Epoch 259/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1500 - mae: 0.3139 - val_loss: 0.1669 - val_mae: 0.3329
# Epoch 260/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1500 - mae: 0.3138 - val_loss: 0.1669 - val_mae: 0.3328
# Epoch 261/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1500 - mae: 0.3137 - val_loss: 0.1669 - val_mae: 0.3327
# Epoch 262/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1499 - mae: 0.3136 - val_loss: 0.1669 - val_mae: 0.3326
# Epoch 263/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1499 - mae: 0.3135 - val_loss: 0.1668 - val_mae: 0.3326
# Epoch 264/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1499 - mae: 0.3134 - val_loss: 0.1668 - val_mae: 0.3325
# Epoch 265/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1498 - mae: 0.3133 - val_loss: 0.1668 - val_mae: 0.3324
# Epoch 266/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1498 - mae: 0.3132 - val_loss: 0.1668 - val_mae: 0.3323
# Epoch 267/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1498 - mae: 0.3131 - val_loss: 0.1668 - val_mae: 0.3322
# Epoch 268/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1497 - mae: 0.3130 - val_loss: 0.1667 - val_mae: 0.3322
# Epoch 269/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1497 - mae: 0.3129 - val_loss: 0.1667 - val_mae: 0.3321
# Epoch 270/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1497 - mae: 0.3129 - val_loss: 0.1667 - val_mae: 0.3320
# Epoch 271/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1496 - mae: 0.3128 - val_loss: 0.1667 - val_mae: 0.3319
# Epoch 272/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1496 - mae: 0.3127 - val_loss: 0.1667 - val_mae: 0.3318
# Epoch 273/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1496 - mae: 0.3126 - val_loss: 0.1667 - val_mae: 0.3318
# Epoch 274/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1495 - mae: 0.3125 - val_loss: 0.1666 - val_mae: 0.3317
# Epoch 275/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1495 - mae: 0.3124 - val_loss: 0.1666 - val_mae: 0.3316
# Epoch 276/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1495 - mae: 0.3124 - val_loss: 0.1666 - val_mae: 0.3316
# Epoch 277/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1495 - mae: 0.3123 - val_loss: 0.1666 - val_mae: 0.3315
# Epoch 278/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1494 - mae: 0.3122 - val_loss: 0.1666 - val_mae: 0.3314
# Epoch 279/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1494 - mae: 0.3121 - val_loss: 0.1666 - val_mae: 0.3313
# Epoch 280/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1494 - mae: 0.3120 - val_loss: 0.1666 - val_mae: 0.3313
# Epoch 281/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1494 - mae: 0.3120 - val_loss: 0.1665 - val_mae: 0.3312
# Epoch 282/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1493 - mae: 0.3119 - val_loss: 0.1665 - val_mae: 0.3311
# Epoch 283/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1493 - mae: 0.3118 - val_loss: 0.1665 - val_mae: 0.3311
# Epoch 284/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1493 - mae: 0.3117 - val_loss: 0.1665 - val_mae: 0.3310
# Epoch 285/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1493 - mae: 0.3117 - val_loss: 0.1665 - val_mae: 0.3309
# Epoch 286/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1493 - mae: 0.3116 - val_loss: 0.1665 - val_mae: 0.3309
# Epoch 287/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1492 - mae: 0.3115 - val_loss: 0.1665 - val_mae: 0.3308
# Epoch 288/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1492 - mae: 0.3115 - val_loss: 0.1664 - val_mae: 0.3307
# Epoch 289/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1492 - mae: 0.3114 - val_loss: 0.1664 - val_mae: 0.3307
# Epoch 290/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1492 - mae: 0.3113 - val_loss: 0.1664 - val_mae: 0.3306
# Epoch 291/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1491 - mae: 0.3112 - val_loss: 0.1664 - val_mae: 0.3305
# Epoch 292/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1491 - mae: 0.3112 - val_loss: 0.1664 - val_mae: 0.3305
# Epoch 293/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1491 - mae: 0.3111 - val_loss: 0.1664 - val_mae: 0.3304
# Epoch 294/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1491 - mae: 0.3110 - val_loss: 0.1664 - val_mae: 0.3303
# Epoch 295/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1491 - mae: 0.3110 - val_loss: 0.1664 - val_mae: 0.3303
# Epoch 296/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1490 - mae: 0.3109 - val_loss: 0.1664 - val_mae: 0.3302
# Epoch 297/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1490 - mae: 0.3109 - val_loss: 0.1663 - val_mae: 0.3301
# Epoch 298/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1490 - mae: 0.3108 - val_loss: 0.1663 - val_mae: 0.3301
# Epoch 299/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1490 - mae: 0.3107 - val_loss: 0.1663 - val_mae: 0.3300
# Epoch 300/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1490 - mae: 0.3107 - val_loss: 0.1663 - val_mae: 0.3300
# Epoch 301/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1489 - mae: 0.3106 - val_loss: 0.1663 - val_mae: 0.3299
# Epoch 302/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1489 - mae: 0.3106 - val_loss: 0.1663 - val_mae: 0.3299
# Epoch 303/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1489 - mae: 0.3105 - val_loss: 0.1663 - val_mae: 0.3298
# Epoch 304/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1489 - mae: 0.3104 - val_loss: 0.1663 - val_mae: 0.3298
# Epoch 305/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1489 - mae: 0.3104 - val_loss: 0.1663 - val_mae: 0.3297
# Epoch 306/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1489 - mae: 0.3103 - val_loss: 0.1663 - val_mae: 0.3296
# Epoch 307/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1488 - mae: 0.3103 - val_loss: 0.1662 - val_mae: 0.3296
# Epoch 308/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1488 - mae: 0.3102 - val_loss: 0.1662 - val_mae: 0.3295
# Epoch 309/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1488 - mae: 0.3101 - val_loss: 0.1662 - val_mae: 0.3295
# Epoch 310/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1488 - mae: 0.3101 - val_loss: 0.1662 - val_mae: 0.3294
# Epoch 311/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1488 - mae: 0.3100 - val_loss: 0.1662 - val_mae: 0.3294
# Epoch 312/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1488 - mae: 0.3100 - val_loss: 0.1662 - val_mae: 0.3293
# Epoch 313/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1487 - mae: 0.3099 - val_loss: 0.1662 - val_mae: 0.3293
# Epoch 314/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1487 - mae: 0.3099 - val_loss: 0.1662 - val_mae: 0.3292
# Epoch 315/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1487 - mae: 0.3098 - val_loss: 0.1662 - val_mae: 0.3292
# Epoch 316/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1487 - mae: 0.3098 - val_loss: 0.1662 - val_mae: 0.3291
# Epoch 317/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1487 - mae: 0.3097 - val_loss: 0.1662 - val_mae: 0.3291
# Epoch 318/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1487 - mae: 0.3097 - val_loss: 0.1662 - val_mae: 0.3290
# Epoch 319/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1487 - mae: 0.3096 - val_loss: 0.1661 - val_mae: 0.3290
# Epoch 320/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1486 - mae: 0.3096 - val_loss: 0.1661 - val_mae: 0.3289
# Epoch 321/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1486 - mae: 0.3095 - val_loss: 0.1661 - val_mae: 0.3289
# Epoch 322/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1486 - mae: 0.3095 - val_loss: 0.1661 - val_mae: 0.3288
# Epoch 323/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1486 - mae: 0.3094 - val_loss: 0.1661 - val_mae: 0.3288
# Epoch 324/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1486 - mae: 0.3094 - val_loss: 0.1661 - val_mae: 0.3288
# Epoch 325/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1486 - mae: 0.3093 - val_loss: 0.1661 - val_mae: 0.3287
# Epoch 326/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1486 - mae: 0.3093 - val_loss: 0.1661 - val_mae: 0.3287
# Epoch 327/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1486 - mae: 0.3092 - val_loss: 0.1661 - val_mae: 0.3286
# Epoch 328/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1485 - mae: 0.3092 - val_loss: 0.1661 - val_mae: 0.3286
# Epoch 329/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1485 - mae: 0.3092 - val_loss: 0.1661 - val_mae: 0.3286
# Epoch 330/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1485 - mae: 0.3091 - val_loss: 0.1661 - val_mae: 0.3285
# Epoch 331/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1485 - mae: 0.3091 - val_loss: 0.1661 - val_mae: 0.3285
# Epoch 332/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1485 - mae: 0.3090 - val_loss: 0.1661 - val_mae: 0.3284
# Epoch 333/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1485 - mae: 0.3090 - val_loss: 0.1660 - val_mae: 0.3284
# Epoch 334/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1485 - mae: 0.3089 - val_loss: 0.1660 - val_mae: 0.3284
# Epoch 335/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1485 - mae: 0.3089 - val_loss: 0.1660 - val_mae: 0.3283
# Epoch 336/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1484 - mae: 0.3088 - val_loss: 0.1660 - val_mae: 0.3283
# Epoch 337/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1484 - mae: 0.3088 - val_loss: 0.1660 - val_mae: 0.3283
# Epoch 338/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1484 - mae: 0.3088 - val_loss: 0.1660 - val_mae: 0.3282
# Epoch 339/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1484 - mae: 0.3087 - val_loss: 0.1660 - val_mae: 0.3282
# Epoch 340/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1484 - mae: 0.3087 - val_loss: 0.1660 - val_mae: 0.3282
# Epoch 341/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1484 - mae: 0.3086 - val_loss: 0.1660 - val_mae: 0.3281
# Epoch 342/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1484 - mae: 0.3086 - val_loss: 0.1660 - val_mae: 0.3281
# Epoch 343/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1484 - mae: 0.3086 - val_loss: 0.1660 - val_mae: 0.3281
# Epoch 344/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1484 - mae: 0.3085 - val_loss: 0.1660 - val_mae: 0.3280
# Epoch 345/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1483 - mae: 0.3085 - val_loss: 0.1660 - val_mae: 0.3280
# Epoch 346/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1483 - mae: 0.3084 - val_loss: 0.1660 - val_mae: 0.3280
# Epoch 347/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1483 - mae: 0.3084 - val_loss: 0.1660 - val_mae: 0.3279
# Epoch 348/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1483 - mae: 0.3084 - val_loss: 0.1660 - val_mae: 0.3279
# Epoch 349/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1483 - mae: 0.3083 - val_loss: 0.1660 - val_mae: 0.3279
# Epoch 350/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1483 - mae: 0.3083 - val_loss: 0.1659 - val_mae: 0.3278
# Epoch 351/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1483 - mae: 0.3083 - val_loss: 0.1659 - val_mae: 0.3278
# Epoch 352/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1483 - mae: 0.3082 - val_loss: 0.1659 - val_mae: 0.3278
# Epoch 353/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1483 - mae: 0.3082 - val_loss: 0.1659 - val_mae: 0.3278
# Epoch 354/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1483 - mae: 0.3082 - val_loss: 0.1659 - val_mae: 0.3277
# Epoch 355/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1482 - mae: 0.3081 - val_loss: 0.1659 - val_mae: 0.3277
# Epoch 356/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1482 - mae: 0.3081 - val_loss: 0.1659 - val_mae: 0.3277
# Epoch 357/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1482 - mae: 0.3081 - val_loss: 0.1659 - val_mae: 0.3277
# Epoch 358/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1482 - mae: 0.3080 - val_loss: 0.1659 - val_mae: 0.3276
# Epoch 359/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1482 - mae: 0.3080 - val_loss: 0.1659 - val_mae: 0.3276
# Epoch 360/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1482 - mae: 0.3080 - val_loss: 0.1659 - val_mae: 0.3276
# Epoch 361/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1482 - mae: 0.3079 - val_loss: 0.1659 - val_mae: 0.3275
# Epoch 362/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1482 - mae: 0.3079 - val_loss: 0.1659 - val_mae: 0.3275
# Epoch 363/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1482 - mae: 0.3079 - val_loss: 0.1659 - val_mae: 0.3275
# Epoch 364/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1482 - mae: 0.3078 - val_loss: 0.1659 - val_mae: 0.3275
# Epoch 365/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1482 - mae: 0.3078 - val_loss: 0.1659 - val_mae: 0.3274
# Epoch 366/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1482 - mae: 0.3078 - val_loss: 0.1659 - val_mae: 0.3274
# Epoch 367/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1481 - mae: 0.3078 - val_loss: 0.1659 - val_mae: 0.3274
# Epoch 368/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1481 - mae: 0.3077 - val_loss: 0.1659 - val_mae: 0.3274
# Epoch 369/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1481 - mae: 0.3077 - val_loss: 0.1659 - val_mae: 0.3273
# Epoch 370/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1481 - mae: 0.3077 - val_loss: 0.1658 - val_mae: 0.3273
# Epoch 371/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1481 - mae: 0.3076 - val_loss: 0.1658 - val_mae: 0.3273
# Epoch 372/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1481 - mae: 0.3076 - val_loss: 0.1658 - val_mae: 0.3273
# Epoch 373/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1481 - mae: 0.3076 - val_loss: 0.1658 - val_mae: 0.3272
# Epoch 374/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1481 - mae: 0.3076 - val_loss: 0.1658 - val_mae: 0.3272
# Epoch 375/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1481 - mae: 0.3075 - val_loss: 0.1658 - val_mae: 0.3272
# Epoch 376/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1481 - mae: 0.3075 - val_loss: 0.1658 - val_mae: 0.3272
# Epoch 377/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1481 - mae: 0.3075 - val_loss: 0.1658 - val_mae: 0.3271
# Epoch 378/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1481 - mae: 0.3074 - val_loss: 0.1658 - val_mae: 0.3271
# Epoch 379/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1481 - mae: 0.3074 - val_loss: 0.1658 - val_mae: 0.3271
# Epoch 380/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1480 - mae: 0.3074 - val_loss: 0.1658 - val_mae: 0.3270
# Epoch 381/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1480 - mae: 0.3074 - val_loss: 0.1658 - val_mae: 0.3270
# Epoch 382/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1480 - mae: 0.3073 - val_loss: 0.1658 - val_mae: 0.3270
# Epoch 383/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1480 - mae: 0.3073 - val_loss: 0.1658 - val_mae: 0.3270
# Epoch 384/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1480 - mae: 0.3073 - val_loss: 0.1658 - val_mae: 0.3269
# Epoch 385/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1480 - mae: 0.3073 - val_loss: 0.1658 - val_mae: 0.3269
# Epoch 386/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1480 - mae: 0.3072 - val_loss: 0.1658 - val_mae: 0.3269
# Epoch 387/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1480 - mae: 0.3072 - val_loss: 0.1658 - val_mae: 0.3269
# Epoch 388/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1480 - mae: 0.3072 - val_loss: 0.1658 - val_mae: 0.3269
# Epoch 389/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1480 - mae: 0.3072 - val_loss: 0.1658 - val_mae: 0.3268
# Epoch 390/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1480 - mae: 0.3071 - val_loss: 0.1658 - val_mae: 0.3268
# Epoch 391/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1480 - mae: 0.3071 - val_loss: 0.1658 - val_mae: 0.3268
# Epoch 392/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1480 - mae: 0.3071 - val_loss: 0.1658 - val_mae: 0.3268
# Epoch 393/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1480 - mae: 0.3071 - val_loss: 0.1658 - val_mae: 0.3267
# Epoch 394/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1480 - mae: 0.3070 - val_loss: 0.1658 - val_mae: 0.3267
# Epoch 395/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mae: 0.3070 - val_loss: 0.1658 - val_mae: 0.3267
# Epoch 396/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mae: 0.3070 - val_loss: 0.1658 - val_mae: 0.3267
# Epoch 397/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mae: 0.3070 - val_loss: 0.1657 - val_mae: 0.3267
# Epoch 398/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mae: 0.3070 - val_loss: 0.1657 - val_mae: 0.3266
# Epoch 399/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mae: 0.3069 - val_loss: 0.1657 - val_mae: 0.3266
# Epoch 400/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1479 - mae: 0.3069 - val_loss: 0.1657 - val_mae: 0.3266
# Epoch 401/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mae: 0.3069 - val_loss: 0.1657 - val_mae: 0.3266
# Epoch 402/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mae: 0.3069 - val_loss: 0.1657 - val_mae: 0.3266
# Epoch 403/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mae: 0.3068 - val_loss: 0.1657 - val_mae: 0.3265
# Epoch 404/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mae: 0.3068 - val_loss: 0.1657 - val_mae: 0.3265
# Epoch 405/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mae: 0.3068 - val_loss: 0.1657 - val_mae: 0.3265
# Epoch 406/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mae: 0.3068 - val_loss: 0.1657 - val_mae: 0.3265
# Epoch 407/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mae: 0.3068 - val_loss: 0.1657 - val_mae: 0.3265
# Epoch 408/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mae: 0.3067 - val_loss: 0.1657 - val_mae: 0.3265
# Epoch 409/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mae: 0.3067 - val_loss: 0.1657 - val_mae: 0.3264
# Epoch 410/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mae: 0.3067 - val_loss: 0.1657 - val_mae: 0.3264
# Epoch 411/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mae: 0.3067 - val_loss: 0.1657 - val_mae: 0.3264
# Epoch 412/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1479 - mae: 0.3067 - val_loss: 0.1657 - val_mae: 0.3264
# Epoch 413/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3066 - val_loss: 0.1657 - val_mae: 0.3264
# Epoch 414/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3066 - val_loss: 0.1657 - val_mae: 0.3263
# Epoch 415/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3066 - val_loss: 0.1657 - val_mae: 0.3263
# Epoch 416/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3066 - val_loss: 0.1657 - val_mae: 0.3263
# Epoch 417/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3065 - val_loss: 0.1657 - val_mae: 0.3263
# Epoch 418/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3065 - val_loss: 0.1657 - val_mae: 0.3263
# Epoch 419/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3065 - val_loss: 0.1657 - val_mae: 0.3263
# Epoch 420/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3065 - val_loss: 0.1657 - val_mae: 0.3262
# Epoch 421/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3065 - val_loss: 0.1657 - val_mae: 0.3262
# Epoch 422/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3064 - val_loss: 0.1657 - val_mae: 0.3262
# Epoch 423/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1478 - mae: 0.3064 - val_loss: 0.1657 - val_mae: 0.3262
# Epoch 424/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3064 - val_loss: 0.1657 - val_mae: 0.3262
# Epoch 425/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3064 - val_loss: 0.1657 - val_mae: 0.3262
# Epoch 426/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3064 - val_loss: 0.1657 - val_mae: 0.3262
# Epoch 427/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3064 - val_loss: 0.1657 - val_mae: 0.3261
# Epoch 428/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3063 - val_loss: 0.1657 - val_mae: 0.3261
# Epoch 429/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3063 - val_loss: 0.1657 - val_mae: 0.3261
# Epoch 430/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3063 - val_loss: 0.1657 - val_mae: 0.3261
# Epoch 431/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3063 - val_loss: 0.1657 - val_mae: 0.3261
# Epoch 432/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1478 - mae: 0.3063 - val_loss: 0.1657 - val_mae: 0.3261
# Epoch 433/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3062 - val_loss: 0.1657 - val_mae: 0.3261
# Epoch 434/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3062 - val_loss: 0.1657 - val_mae: 0.3261
# Epoch 435/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3062 - val_loss: 0.1657 - val_mae: 0.3260
# Epoch 436/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1477 - mae: 0.3062 - val_loss: 0.1657 - val_mae: 0.3260
# Epoch 437/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3062 - val_loss: 0.1657 - val_mae: 0.3260
# Epoch 438/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3062 - val_loss: 0.1657 - val_mae: 0.3260
# Epoch 439/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3061 - val_loss: 0.1657 - val_mae: 0.3260
# Epoch 440/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3061 - val_loss: 0.1657 - val_mae: 0.3260
# Epoch 441/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3061 - val_loss: 0.1657 - val_mae: 0.3260
# Epoch 442/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3061 - val_loss: 0.1657 - val_mae: 0.3260
# Epoch 443/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3061 - val_loss: 0.1657 - val_mae: 0.3259
# Epoch 444/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3061 - val_loss: 0.1657 - val_mae: 0.3259
# Epoch 445/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3060 - val_loss: 0.1657 - val_mae: 0.3259
# Epoch 446/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3060 - val_loss: 0.1657 - val_mae: 0.3259
# Epoch 447/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1477 - mae: 0.3060 - val_loss: 0.1657 - val_mae: 0.3259
# Epoch 448/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3060 - val_loss: 0.1656 - val_mae: 0.3259
# Epoch 449/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3060 - val_loss: 0.1656 - val_mae: 0.3259
# Epoch 450/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3060 - val_loss: 0.1656 - val_mae: 0.3259
# Epoch 451/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3059 - val_loss: 0.1656 - val_mae: 0.3258
# Epoch 452/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3059 - val_loss: 0.1656 - val_mae: 0.3258
# Epoch 453/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3059 - val_loss: 0.1656 - val_mae: 0.3258
# Epoch 454/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - mae: 0.3059 - val_loss: 0.1656 - val_mae: 0.3258
# Epoch 455/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3059 - val_loss: 0.1656 - val_mae: 0.3258
# Epoch 456/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3059 - val_loss: 0.1656 - val_mae: 0.3258
# Epoch 457/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3059 - val_loss: 0.1656 - val_mae: 0.3258
# Epoch 458/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1476 - mae: 0.3058 - val_loss: 0.1656 - val_mae: 0.3258
# Epoch 459/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3058 - val_loss: 0.1656 - val_mae: 0.3258
# Epoch 460/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3058 - val_loss: 0.1656 - val_mae: 0.3257
# Epoch 461/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3058 - val_loss: 0.1656 - val_mae: 0.3257
# Epoch 462/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3058 - val_loss: 0.1656 - val_mae: 0.3257
# Epoch 463/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3058 - val_loss: 0.1656 - val_mae: 0.3257
# Epoch 464/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3058 - val_loss: 0.1656 - val_mae: 0.3257
# Epoch 465/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3057 - val_loss: 0.1656 - val_mae: 0.3257
# Epoch 466/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3057 - val_loss: 0.1656 - val_mae: 0.3257
# Epoch 467/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3057 - val_loss: 0.1656 - val_mae: 0.3257
# Epoch 468/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1476 - mae: 0.3057 - val_loss: 0.1656 - val_mae: 0.3257
# Epoch 469/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3057 - val_loss: 0.1656 - val_mae: 0.3257
# Epoch 470/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3057 - val_loss: 0.1656 - val_mae: 0.3256
# Epoch 471/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3057 - val_loss: 0.1656 - val_mae: 0.3256
# Epoch 472/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3056 - val_loss: 0.1656 - val_mae: 0.3256
# Epoch 473/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3056 - val_loss: 0.1656 - val_mae: 0.3256
# Epoch 474/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3056 - val_loss: 0.1656 - val_mae: 0.3256
# Epoch 475/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3056 - val_loss: 0.1656 - val_mae: 0.3256
# Epoch 476/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3056 - val_loss: 0.1656 - val_mae: 0.3256
# Epoch 477/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3056 - val_loss: 0.1656 - val_mae: 0.3256
# Epoch 478/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1476 - mae: 0.3056 - val_loss: 0.1656 - val_mae: 0.3256
# Epoch 479/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3055 - val_loss: 0.1656 - val_mae: 0.3256
# Epoch 480/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1476 - mae: 0.3055 - val_loss: 0.1656 - val_mae: 0.3256
# Epoch 481/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3055 - val_loss: 0.1656 - val_mae: 0.3255
# Epoch 482/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3055 - val_loss: 0.1656 - val_mae: 0.3255
# Epoch 483/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3055 - val_loss: 0.1656 - val_mae: 0.3255
# Epoch 484/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3055 - val_loss: 0.1656 - val_mae: 0.3255
# Epoch 485/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3055 - val_loss: 0.1656 - val_mae: 0.3255
# Epoch 486/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1475 - mae: 0.3054 - val_loss: 0.1656 - val_mae: 0.3255
# Epoch 487/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3054 - val_loss: 0.1656 - val_mae: 0.3255
# Epoch 488/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3054 - val_loss: 0.1656 - val_mae: 0.3255
# Epoch 489/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3054 - val_loss: 0.1656 - val_mae: 0.3255
# Epoch 490/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3054 - val_loss: 0.1656 - val_mae: 0.3255
# Epoch 491/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3054 - val_loss: 0.1656 - val_mae: 0.3255
# Epoch 492/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3054 - val_loss: 0.1656 - val_mae: 0.3254
# Epoch 493/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3053 - val_loss: 0.1656 - val_mae: 0.3254
# Epoch 494/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3053 - val_loss: 0.1656 - val_mae: 0.3254
# Epoch 495/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3053 - val_loss: 0.1656 - val_mae: 0.3254
# Epoch 496/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1475 - mae: 0.3053 - val_loss: 0.1656 - val_mae: 0.3254
# Epoch 497/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3053 - val_loss: 0.1656 - val_mae: 0.3254
# Epoch 498/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3053 - val_loss: 0.1656 - val_mae: 0.3254
# Epoch 499/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3053 - val_loss: 0.1656 - val_mae: 0.3254
# Epoch 500/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1475 - mae: 0.3052 - val_loss: 0.1656 - val_mae: 0.3254

# %% [markdown]
# ### Plot Metrics

# %% [markdown]
# #### Loss (or Mean Squared Error)
#
# During training, the model's performance is constantly being measured against both our training data and the validation data that we set aside earlier. Training produces a log of data that tells us how the model's performance changed over the course of the training process.
#
# The following cells will display some of that data in a graphical form:

# %%
# Draw a graph of the loss, which is the distance between
# the predicted and actual values during training and validation.
train_loss = history_small.history['loss']
val_loss = history_small.history['val_loss']

epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, 'g.', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# The graph shows the _loss_ (or the difference between the model's predictions and the actual data) for each epoch. There are several ways to calculate loss, and the method we have used is _mean squared error_. There is a distinct loss value given for the training and the validation data.
#
# As we can see, the amount of loss rapidly decreases over the first 25 epochs, before flattening out. This means that the model is improving and producing more accurate predictions!
#
# Our goal is to stop training when either the model is no longer improving, or when the _training loss_ is less than the _validation loss_, which would mean that the model has learned to predict the training data so well that it can no longer generalize to new data.
#
# To make the flatter part of the graph more readable, let's skip the first 50 epochs:

# %%
# Exclude the first few epochs so the graph is easier to read
SKIP = 50

plt.plot(epochs[SKIP:], train_loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'r.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# From the plot, we can see that loss continues to reduce until around 200 epochs, at which point it is mostly stable. This means that there's no need to train our network beyond 200 epochs.
#
# However, we can also see that the lowest loss value is still around 0.155. This means that our network's predictions are off by an average of ~15%. In addition, the validation loss values jump around a lot, and is sometimes even higher.
#
# #### Mean Absolute Error
#
# To gain more insight into our model's performance we can plot some more data. This time, we'll plot the _mean absolute error_, which is another way of measuring how far the network's predictions are from the actual numbers:

# %%
plt.clf()

# Draw a graph of mean absolute error, which is another way of
# measuring the amount of error in the prediction.
train_mae = history_small.history['mae']
val_mae = history_small.history['val_mae']

plt.plot(epochs[SKIP:], train_mae[SKIP:], 'g.', label='Training MAE')
plt.plot(epochs[SKIP:], val_mae[SKIP:], 'r.', label='Validation MAE')
plt.title('Training and validation mean absolute error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %% [markdown]
# This graph of _mean absolute error_ tells another story. We can see that training data shows consistently lower error than validation data, which means that the network may have _overfit_, or learned the training data so rigidly that it can't make effective predictions about new data.
#
# In addition, the mean absolute error values are quite high, ~0.305 at best, which means some of the model's predictions are at least 30% off. A 30% error means we are very far from accurately modelling the sine wave function.
#
# #### Actual vs Predicted Outputs
#
# To get more insight into what is happening, let's check its predictions against the test dataset we set aside earlier:

# %%
# Calculate and print the loss on our test dataset
test_loss, test_mae = model_small.evaluate(x_test, y_test)

# Make predictions based on our test dataset
y_test_pred = model_small.predict(x_test)

# Graph the predictions against the actual values
plt.clf()
plt.title('Comparison of predictions and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual values')
plt.plot(x_test, y_test_pred, 'r.', label='TF predictions')
plt.legend()
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1353 - mae: 0.2976
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# Oh dear! The graph makes it clear that our network has learned to approximate the sine function in a very limited way.
#
# The rigidity of this fit suggests that the model does not have enough capacity to learn the full complexity of the sine wave function, so it's only able to approximate it in an overly simplistic way. By making our model bigger, we should be able to improve its performance.

# %% [markdown]
# ## Training a Larger Model

# %% [markdown]
# ### Design the Model
# To make our model bigger, let's add an additional layer of neurons. The following cell redefines our model in the same way as earlier, but with 16 neurons in the first layer and an additional layer of 16 neurons in the middle:

# %%
model_large = keras.Sequential()

# Add an Input layer as the first layer
model_large.add(keras.Input(shape=(1,)))

# First layer takes a scalar input and feeds it through 16 "neurons". The
# neurons decide whether to activate based on the 'relu' activation function.
model_large.add(keras.layers.Dense(16, activation='relu'))

# The new second and third layer will help the network learn more complex
# representations
model_large.add(keras.layers.Dense(16, activation='relu'))

# Final layer is a single neuron, since we want to output a single value
model_large.add(keras.layers.Dense(1))

# Compile the model using the standard 'adam' optimizer and the mean squared
# error or 'mse' loss function for regression.
model_large.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Model summary
model_large.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 16)             │            32 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 321 (1.25 KB)
#  Trainable params: 321 (1.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train the Model ###
#
# We'll now train and save the new model.

# %%
# Train the model
history_large = model_large.fit(
    x_train, 
    y_train,
    epochs=500,  # Fewer epochs for a smaller model
    batch_size=64,
    validation_data=(x_validate, y_validate))

# Save the model
model_large.save(MODEL_KERAS)
# Out:
# Epoch 1/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.4464 - mae: 0.5530 - val_loss: 0.4330 - val_mae: 0.5654
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4205 - mae: 0.5517 - val_loss: 0.4260 - val_mae: 0.5656
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4112 - mae: 0.5532 - val_loss: 0.4126 - val_mae: 0.5591
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3967 - mae: 0.5452 - val_loss: 0.3961 - val_mae: 0.5468
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3808 - mae: 0.5296 - val_loss: 0.3801 - val_mae: 0.5336
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3668 - mae: 0.5165 - val_loss: 0.3663 - val_mae: 0.5251
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3530 - mae: 0.5070 - val_loss: 0.3509 - val_mae: 0.5142
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3356 - mae: 0.4951 - val_loss: 0.3297 - val_mae: 0.5021
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3155 - mae: 0.4826 - val_loss: 0.3099 - val_mae: 0.4865
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2969 - mae: 0.4660 - val_loss: 0.2918 - val_mae: 0.4722
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2800 - mae: 0.4519 - val_loss: 0.2757 - val_mae: 0.4602
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2645 - mae: 0.4405 - val_loss: 0.2609 - val_mae: 0.4493
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2499 - mae: 0.4289 - val_loss: 0.2467 - val_mae: 0.4374
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2362 - mae: 0.4174 - val_loss: 0.2335 - val_mae: 0.4256
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2235 - mae: 0.4062 - val_loss: 0.2215 - val_mae: 0.4145
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2118 - mae: 0.3955 - val_loss: 0.2105 - val_mae: 0.4041
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2009 - mae: 0.3851 - val_loss: 0.2004 - val_mae: 0.3942
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1910 - mae: 0.3755 - val_loss: 0.1914 - val_mae: 0.3848
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1821 - mae: 0.3661 - val_loss: 0.1832 - val_mae: 0.3757
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1739 - mae: 0.3571 - val_loss: 0.1757 - val_mae: 0.3669
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1665 - mae: 0.3477 - val_loss: 0.1680 - val_mae: 0.3566
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1586 - mae: 0.3383 - val_loss: 0.1618 - val_mae: 0.3474
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1525 - mae: 0.3301 - val_loss: 0.1567 - val_mae: 0.3395
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1469 - mae: 0.3224 - val_loss: 0.1523 - val_mae: 0.3324
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1423 - mae: 0.3157 - val_loss: 0.1488 - val_mae: 0.3258
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1383 - mae: 0.3094 - val_loss: 0.1454 - val_mae: 0.3192
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1346 - mae: 0.3038 - val_loss: 0.1401 - val_mae: 0.3114
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1276 - mae: 0.2953 - val_loss: 0.1273 - val_mae: 0.2974
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1193 - mae: 0.2860 - val_loss: 0.1258 - val_mae: 0.2957
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1162 - mae: 0.2800 - val_loss: 0.1217 - val_mae: 0.2885
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1119 - mae: 0.2734 - val_loss: 0.1189 - val_mae: 0.2828
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1091 - mae: 0.2681 - val_loss: 0.1168 - val_mae: 0.2790
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1067 - mae: 0.2635 - val_loss: 0.1150 - val_mae: 0.2756
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1045 - mae: 0.2597 - val_loss: 0.1134 - val_mae: 0.2725
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1026 - mae: 0.2563 - val_loss: 0.1120 - val_mae: 0.2696
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1010 - mae: 0.2531 - val_loss: 0.1107 - val_mae: 0.2671
# Epoch 37/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0995 - mae: 0.2502 - val_loss: 0.1096 - val_mae: 0.2647
# Epoch 38/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0981 - mae: 0.2476 - val_loss: 0.1085 - val_mae: 0.2626
# Epoch 39/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0969 - mae: 0.2453 - val_loss: 0.1076 - val_mae: 0.2608
# Epoch 40/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0959 - mae: 0.2431 - val_loss: 0.1067 - val_mae: 0.2588
# Epoch 41/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0948 - mae: 0.2410 - val_loss: 0.1058 - val_mae: 0.2566
# Epoch 42/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0939 - mae: 0.2389 - val_loss: 0.1049 - val_mae: 0.2545
# Epoch 43/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0929 - mae: 0.2369 - val_loss: 0.1041 - val_mae: 0.2524
# Epoch 44/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0921 - mae: 0.2349 - val_loss: 0.1032 - val_mae: 0.2503
# Epoch 45/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0912 - mae: 0.2331 - val_loss: 0.1025 - val_mae: 0.2487
# Epoch 46/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0905 - mae: 0.2316 - val_loss: 0.1018 - val_mae: 0.2473
# Epoch 47/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0898 - mae: 0.2300 - val_loss: 0.1013 - val_mae: 0.2460
# Epoch 48/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0891 - mae: 0.2286 - val_loss: 0.1007 - val_mae: 0.2447
# Epoch 49/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0884 - mae: 0.2273 - val_loss: 0.1001 - val_mae: 0.2434
# Epoch 50/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0879 - mae: 0.2261 - val_loss: 0.0995 - val_mae: 0.2422
# Epoch 51/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0873 - mae: 0.2249 - val_loss: 0.0989 - val_mae: 0.2410
# Epoch 52/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0868 - mae: 0.2239 - val_loss: 0.0984 - val_mae: 0.2400
# Epoch 53/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0862 - mae: 0.2228 - val_loss: 0.0979 - val_mae: 0.2389
# Epoch 54/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0857 - mae: 0.2218 - val_loss: 0.0974 - val_mae: 0.2379
# Epoch 55/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0852 - mae: 0.2209 - val_loss: 0.0969 - val_mae: 0.2369
# Epoch 56/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0847 - mae: 0.2200 - val_loss: 0.0964 - val_mae: 0.2359
# Epoch 57/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0842 - mae: 0.2190 - val_loss: 0.0959 - val_mae: 0.2348
# Epoch 58/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0837 - mae: 0.2181 - val_loss: 0.0953 - val_mae: 0.2337
# Epoch 59/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0832 - mae: 0.2172 - val_loss: 0.0948 - val_mae: 0.2326
# Epoch 60/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0827 - mae: 0.2163 - val_loss: 0.0943 - val_mae: 0.2317
# Epoch 61/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0823 - mae: 0.2155 - val_loss: 0.0938 - val_mae: 0.2306
# Epoch 62/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0818 - mae: 0.2146 - val_loss: 0.0933 - val_mae: 0.2296
# Epoch 63/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0814 - mae: 0.2138 - val_loss: 0.0928 - val_mae: 0.2286
# Epoch 64/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0809 - mae: 0.2129 - val_loss: 0.0923 - val_mae: 0.2277
# Epoch 65/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0805 - mae: 0.2121 - val_loss: 0.0918 - val_mae: 0.2267
# Epoch 66/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0800 - mae: 0.2113 - val_loss: 0.0914 - val_mae: 0.2258
# Epoch 67/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0796 - mae: 0.2105 - val_loss: 0.0909 - val_mae: 0.2248
# Epoch 68/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0791 - mae: 0.2096 - val_loss: 0.0904 - val_mae: 0.2239
# Epoch 69/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0787 - mae: 0.2086 - val_loss: 0.0900 - val_mae: 0.2231
# Epoch 70/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0782 - mae: 0.2078 - val_loss: 0.0895 - val_mae: 0.2223
# Epoch 71/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0778 - mae: 0.2070 - val_loss: 0.0891 - val_mae: 0.2215
# Epoch 72/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0774 - mae: 0.2063 - val_loss: 0.0887 - val_mae: 0.2207
# Epoch 73/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0770 - mae: 0.2056 - val_loss: 0.0882 - val_mae: 0.2200
# Epoch 74/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0766 - mae: 0.2049 - val_loss: 0.0878 - val_mae: 0.2193
# Epoch 75/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0762 - mae: 0.2043 - val_loss: 0.0874 - val_mae: 0.2185
# Epoch 76/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0758 - mae: 0.2036 - val_loss: 0.0870 - val_mae: 0.2178
# Epoch 77/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0755 - mae: 0.2029 - val_loss: 0.0866 - val_mae: 0.2171
# Epoch 78/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0751 - mae: 0.2023 - val_loss: 0.0862 - val_mae: 0.2165
# Epoch 79/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0747 - mae: 0.2017 - val_loss: 0.0858 - val_mae: 0.2158
# Epoch 80/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0744 - mae: 0.2011 - val_loss: 0.0854 - val_mae: 0.2152
# Epoch 81/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0740 - mae: 0.2005 - val_loss: 0.0850 - val_mae: 0.2146
# Epoch 82/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0737 - mae: 0.1999 - val_loss: 0.0847 - val_mae: 0.2139
# Epoch 83/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0733 - mae: 0.1993 - val_loss: 0.0843 - val_mae: 0.2133
# Epoch 84/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0730 - mae: 0.1987 - val_loss: 0.0839 - val_mae: 0.2126
# Epoch 85/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0726 - mae: 0.1980 - val_loss: 0.0835 - val_mae: 0.2121
# Epoch 86/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0723 - mae: 0.1975 - val_loss: 0.0832 - val_mae: 0.2115
# Epoch 87/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0720 - mae: 0.1970 - val_loss: 0.0828 - val_mae: 0.2109
# Epoch 88/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0716 - mae: 0.1964 - val_loss: 0.0824 - val_mae: 0.2104
# Epoch 89/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0713 - mae: 0.1958 - val_loss: 0.0821 - val_mae: 0.2098
# Epoch 90/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0710 - mae: 0.1953 - val_loss: 0.0817 - val_mae: 0.2093
# Epoch 91/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0706 - mae: 0.1948 - val_loss: 0.0814 - val_mae: 0.2088
# Epoch 92/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0703 - mae: 0.1943 - val_loss: 0.0810 - val_mae: 0.2083
# Epoch 93/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0700 - mae: 0.1938 - val_loss: 0.0807 - val_mae: 0.2078
# Epoch 94/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0697 - mae: 0.1933 - val_loss: 0.0804 - val_mae: 0.2074
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0694 - mae: 0.1929 - val_loss: 0.0801 - val_mae: 0.2069
# Epoch 96/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0691 - mae: 0.1924 - val_loss: 0.0797 - val_mae: 0.2064
# Epoch 97/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0689 - mae: 0.1919 - val_loss: 0.0794 - val_mae: 0.2059
# Epoch 98/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0686 - mae: 0.1914 - val_loss: 0.0791 - val_mae: 0.2054
# Epoch 99/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0683 - mae: 0.1909 - val_loss: 0.0788 - val_mae: 0.2049
# Epoch 100/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0680 - mae: 0.1905 - val_loss: 0.0785 - val_mae: 0.2045
# Epoch 101/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0677 - mae: 0.1901 - val_loss: 0.0781 - val_mae: 0.2040
# Epoch 102/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0674 - mae: 0.1896 - val_loss: 0.0778 - val_mae: 0.2035
# Epoch 103/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0672 - mae: 0.1892 - val_loss: 0.0775 - val_mae: 0.2030
# Epoch 104/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0669 - mae: 0.1887 - val_loss: 0.0772 - val_mae: 0.2025
# Epoch 105/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0666 - mae: 0.1882 - val_loss: 0.0769 - val_mae: 0.2021
# Epoch 106/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0663 - mae: 0.1878 - val_loss: 0.0765 - val_mae: 0.2016
# Epoch 107/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0660 - mae: 0.1873 - val_loss: 0.0762 - val_mae: 0.2011
# Epoch 108/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0657 - mae: 0.1867 - val_loss: 0.0759 - val_mae: 0.2007
# Epoch 109/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0654 - mae: 0.1863 - val_loss: 0.0755 - val_mae: 0.2002
# Epoch 110/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0651 - mae: 0.1858 - val_loss: 0.0752 - val_mae: 0.1998
# Epoch 111/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0648 - mae: 0.1852 - val_loss: 0.0749 - val_mae: 0.1993
# Epoch 112/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0645 - mae: 0.1846 - val_loss: 0.0745 - val_mae: 0.1989
# Epoch 113/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0642 - mae: 0.1841 - val_loss: 0.0742 - val_mae: 0.1984
# Epoch 114/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0639 - mae: 0.1836 - val_loss: 0.0739 - val_mae: 0.1980
# Epoch 115/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0637 - mae: 0.1831 - val_loss: 0.0736 - val_mae: 0.1976
# Epoch 116/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0634 - mae: 0.1826 - val_loss: 0.0732 - val_mae: 0.1971
# Epoch 117/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0631 - mae: 0.1822 - val_loss: 0.0729 - val_mae: 0.1966
# Epoch 118/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0628 - mae: 0.1817 - val_loss: 0.0726 - val_mae: 0.1962
# Epoch 119/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0625 - mae: 0.1813 - val_loss: 0.0722 - val_mae: 0.1957
# Epoch 120/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0622 - mae: 0.1808 - val_loss: 0.0719 - val_mae: 0.1953
# Epoch 121/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0619 - mae: 0.1803 - val_loss: 0.0716 - val_mae: 0.1949
# Epoch 122/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0616 - mae: 0.1798 - val_loss: 0.0713 - val_mae: 0.1944
# Epoch 123/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0614 - mae: 0.1793 - val_loss: 0.0709 - val_mae: 0.1940
# Epoch 124/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0611 - mae: 0.1788 - val_loss: 0.0706 - val_mae: 0.1935
# Epoch 125/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0608 - mae: 0.1783 - val_loss: 0.0703 - val_mae: 0.1931
# Epoch 126/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0605 - mae: 0.1779 - val_loss: 0.0699 - val_mae: 0.1927
# Epoch 127/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0602 - mae: 0.1774 - val_loss: 0.0696 - val_mae: 0.1922
# Epoch 128/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0599 - mae: 0.1769 - val_loss: 0.0693 - val_mae: 0.1918
# Epoch 129/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0596 - mae: 0.1765 - val_loss: 0.0689 - val_mae: 0.1914
# Epoch 130/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0593 - mae: 0.1760 - val_loss: 0.0686 - val_mae: 0.1909
# Epoch 131/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0591 - mae: 0.1755 - val_loss: 0.0683 - val_mae: 0.1905
# Epoch 132/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0588 - mae: 0.1751 - val_loss: 0.0679 - val_mae: 0.1900
# Epoch 133/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0585 - mae: 0.1747 - val_loss: 0.0676 - val_mae: 0.1896
# Epoch 134/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0582 - mae: 0.1742 - val_loss: 0.0673 - val_mae: 0.1891
# Epoch 135/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0579 - mae: 0.1737 - val_loss: 0.0669 - val_mae: 0.1886
# Epoch 136/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0576 - mae: 0.1732 - val_loss: 0.0666 - val_mae: 0.1882
# Epoch 137/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0573 - mae: 0.1727 - val_loss: 0.0662 - val_mae: 0.1877
# Epoch 138/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0570 - mae: 0.1722 - val_loss: 0.0659 - val_mae: 0.1871
# Epoch 139/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0567 - mae: 0.1717 - val_loss: 0.0655 - val_mae: 0.1866
# Epoch 140/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0564 - mae: 0.1712 - val_loss: 0.0652 - val_mae: 0.1862
# Epoch 141/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0561 - mae: 0.1707 - val_loss: 0.0648 - val_mae: 0.1857
# Epoch 142/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0558 - mae: 0.1703 - val_loss: 0.0645 - val_mae: 0.1852
# Epoch 143/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0555 - mae: 0.1697 - val_loss: 0.0641 - val_mae: 0.1847
# Epoch 144/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0552 - mae: 0.1692 - val_loss: 0.0638 - val_mae: 0.1842
# Epoch 145/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0549 - mae: 0.1688 - val_loss: 0.0634 - val_mae: 0.1837
# Epoch 146/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0546 - mae: 0.1682 - val_loss: 0.0631 - val_mae: 0.1832
# Epoch 147/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0543 - mae: 0.1678 - val_loss: 0.0627 - val_mae: 0.1827
# Epoch 148/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0540 - mae: 0.1673 - val_loss: 0.0624 - val_mae: 0.1823
# Epoch 149/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0537 - mae: 0.1668 - val_loss: 0.0620 - val_mae: 0.1817
# Epoch 150/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0534 - mae: 0.1662 - val_loss: 0.0617 - val_mae: 0.1812
# Epoch 151/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0531 - mae: 0.1657 - val_loss: 0.0613 - val_mae: 0.1808
# Epoch 152/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0528 - mae: 0.1653 - val_loss: 0.0609 - val_mae: 0.1803
# Epoch 153/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0525 - mae: 0.1647 - val_loss: 0.0606 - val_mae: 0.1798
# Epoch 154/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0522 - mae: 0.1642 - val_loss: 0.0602 - val_mae: 0.1793
# Epoch 155/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0519 - mae: 0.1636 - val_loss: 0.0599 - val_mae: 0.1788
# Epoch 156/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0516 - mae: 0.1631 - val_loss: 0.0595 - val_mae: 0.1783
# Epoch 157/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0513 - mae: 0.1626 - val_loss: 0.0591 - val_mae: 0.1778
# Epoch 158/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0509 - mae: 0.1621 - val_loss: 0.0588 - val_mae: 0.1773
# Epoch 159/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0506 - mae: 0.1615 - val_loss: 0.0584 - val_mae: 0.1768
# Epoch 160/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0503 - mae: 0.1610 - val_loss: 0.0580 - val_mae: 0.1763
# Epoch 161/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0500 - mae: 0.1603 - val_loss: 0.0577 - val_mae: 0.1758
# Epoch 162/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0497 - mae: 0.1596 - val_loss: 0.0573 - val_mae: 0.1752
# Epoch 163/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0494 - mae: 0.1590 - val_loss: 0.0569 - val_mae: 0.1746
# Epoch 164/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mae: 0.1583 - val_loss: 0.0565 - val_mae: 0.1740
# Epoch 165/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mae: 0.1578 - val_loss: 0.0561 - val_mae: 0.1734
# Epoch 166/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0483 - mae: 0.1572 - val_loss: 0.0557 - val_mae: 0.1728
# Epoch 167/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0480 - mae: 0.1566 - val_loss: 0.0553 - val_mae: 0.1722
# Epoch 168/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0477 - mae: 0.1559 - val_loss: 0.0550 - val_mae: 0.1718
# Epoch 169/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0473 - mae: 0.1553 - val_loss: 0.0546 - val_mae: 0.1713
# Epoch 170/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0470 - mae: 0.1548 - val_loss: 0.0542 - val_mae: 0.1709
# Epoch 171/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0467 - mae: 0.1544 - val_loss: 0.0538 - val_mae: 0.1704
# Epoch 172/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0463 - mae: 0.1538 - val_loss: 0.0534 - val_mae: 0.1699
# Epoch 173/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0460 - mae: 0.1533 - val_loss: 0.0530 - val_mae: 0.1693
# Epoch 174/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0457 - mae: 0.1528 - val_loss: 0.0526 - val_mae: 0.1688
# Epoch 175/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0454 - mae: 0.1523 - val_loss: 0.0522 - val_mae: 0.1682
# Epoch 176/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0450 - mae: 0.1518 - val_loss: 0.0518 - val_mae: 0.1675
# Epoch 177/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0447 - mae: 0.1512 - val_loss: 0.0514 - val_mae: 0.1670
# Epoch 178/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0444 - mae: 0.1508 - val_loss: 0.0510 - val_mae: 0.1664
# Epoch 179/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0440 - mae: 0.1502 - val_loss: 0.0506 - val_mae: 0.1660
# Epoch 180/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0437 - mae: 0.1498 - val_loss: 0.0502 - val_mae: 0.1654
# Epoch 181/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0434 - mae: 0.1492 - val_loss: 0.0498 - val_mae: 0.1649
# Epoch 182/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0430 - mae: 0.1486 - val_loss: 0.0494 - val_mae: 0.1643
# Epoch 183/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0427 - mae: 0.1481 - val_loss: 0.0489 - val_mae: 0.1636
# Epoch 184/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0424 - mae: 0.1475 - val_loss: 0.0485 - val_mae: 0.1631
# Epoch 185/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0420 - mae: 0.1470 - val_loss: 0.0481 - val_mae: 0.1624
# Epoch 186/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0417 - mae: 0.1465 - val_loss: 0.0476 - val_mae: 0.1617
# Epoch 187/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0413 - mae: 0.1459 - val_loss: 0.0472 - val_mae: 0.1612
# Epoch 188/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0410 - mae: 0.1454 - val_loss: 0.0468 - val_mae: 0.1604
# Epoch 189/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0407 - mae: 0.1448 - val_loss: 0.0463 - val_mae: 0.1597
# Epoch 190/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0403 - mae: 0.1443 - val_loss: 0.0459 - val_mae: 0.1589
# Epoch 191/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0400 - mae: 0.1437 - val_loss: 0.0455 - val_mae: 0.1583
# Epoch 192/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0396 - mae: 0.1432 - val_loss: 0.0450 - val_mae: 0.1576
# Epoch 193/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0393 - mae: 0.1426 - val_loss: 0.0446 - val_mae: 0.1568
# Epoch 194/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0389 - mae: 0.1421 - val_loss: 0.0441 - val_mae: 0.1562
# Epoch 195/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0386 - mae: 0.1415 - val_loss: 0.0437 - val_mae: 0.1554
# Epoch 196/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0382 - mae: 0.1409 - val_loss: 0.0432 - val_mae: 0.1544
# Epoch 197/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0379 - mae: 0.1403 - val_loss: 0.0427 - val_mae: 0.1537
# Epoch 198/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0375 - mae: 0.1398 - val_loss: 0.0423 - val_mae: 0.1528
# Epoch 199/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0372 - mae: 0.1391 - val_loss: 0.0418 - val_mae: 0.1521
# Epoch 200/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0368 - mae: 0.1385 - val_loss: 0.0413 - val_mae: 0.1513
# Epoch 201/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0365 - mae: 0.1379 - val_loss: 0.0409 - val_mae: 0.1506
# Epoch 202/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0361 - mae: 0.1373 - val_loss: 0.0404 - val_mae: 0.1497
# Epoch 203/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0358 - mae: 0.1367 - val_loss: 0.0400 - val_mae: 0.1490
# Epoch 204/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0354 - mae: 0.1361 - val_loss: 0.0395 - val_mae: 0.1482
# Epoch 205/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0351 - mae: 0.1356 - val_loss: 0.0391 - val_mae: 0.1473
# Epoch 206/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0348 - mae: 0.1350 - val_loss: 0.0386 - val_mae: 0.1465
# Epoch 207/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0344 - mae: 0.1344 - val_loss: 0.0381 - val_mae: 0.1456
# Epoch 208/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0341 - mae: 0.1337 - val_loss: 0.0377 - val_mae: 0.1447
# Epoch 209/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0337 - mae: 0.1331 - val_loss: 0.0372 - val_mae: 0.1439
# Epoch 210/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0334 - mae: 0.1326 - val_loss: 0.0368 - val_mae: 0.1432
# Epoch 211/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0331 - mae: 0.1320 - val_loss: 0.0364 - val_mae: 0.1424
# Epoch 212/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0327 - mae: 0.1314 - val_loss: 0.0359 - val_mae: 0.1416
# Epoch 213/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0324 - mae: 0.1307 - val_loss: 0.0355 - val_mae: 0.1408
# Epoch 214/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0320 - mae: 0.1301 - val_loss: 0.0350 - val_mae: 0.1400
# Epoch 215/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0317 - mae: 0.1294 - val_loss: 0.0346 - val_mae: 0.1391
# Epoch 216/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0314 - mae: 0.1287 - val_loss: 0.0341 - val_mae: 0.1385
# Epoch 217/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0311 - mae: 0.1283 - val_loss: 0.0337 - val_mae: 0.1377
# Epoch 218/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0307 - mae: 0.1276 - val_loss: 0.0333 - val_mae: 0.1369
# Epoch 219/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0304 - mae: 0.1270 - val_loss: 0.0328 - val_mae: 0.1361
# Epoch 220/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0301 - mae: 0.1265 - val_loss: 0.0324 - val_mae: 0.1355
# Epoch 221/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0298 - mae: 0.1259 - val_loss: 0.0320 - val_mae: 0.1347
# Epoch 222/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0295 - mae: 0.1253 - val_loss: 0.0316 - val_mae: 0.1339
# Epoch 223/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0292 - mae: 0.1247 - val_loss: 0.0312 - val_mae: 0.1332
# Epoch 224/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0289 - mae: 0.1242 - val_loss: 0.0308 - val_mae: 0.1324
# Epoch 225/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0286 - mae: 0.1236 - val_loss: 0.0304 - val_mae: 0.1317
# Epoch 226/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0283 - mae: 0.1231 - val_loss: 0.0300 - val_mae: 0.1309
# Epoch 227/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0279 - mae: 0.1223 - val_loss: 0.0296 - val_mae: 0.1302
# Epoch 228/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0276 - mae: 0.1218 - val_loss: 0.0292 - val_mae: 0.1295
# Epoch 229/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0274 - mae: 0.1213 - val_loss: 0.0288 - val_mae: 0.1287
# Epoch 230/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0271 - mae: 0.1208 - val_loss: 0.0284 - val_mae: 0.1278
# Epoch 231/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0268 - mae: 0.1201 - val_loss: 0.0280 - val_mae: 0.1270
# Epoch 232/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0265 - mae: 0.1196 - val_loss: 0.0277 - val_mae: 0.1263
# Epoch 233/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0262 - mae: 0.1190 - val_loss: 0.0273 - val_mae: 0.1256
# Epoch 234/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0259 - mae: 0.1184 - val_loss: 0.0269 - val_mae: 0.1250
# Epoch 235/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0256 - mae: 0.1179 - val_loss: 0.0266 - val_mae: 0.1243
# Epoch 236/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0253 - mae: 0.1173 - val_loss: 0.0262 - val_mae: 0.1237
# Epoch 237/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0250 - mae: 0.1168 - val_loss: 0.0259 - val_mae: 0.1231
# Epoch 238/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0248 - mae: 0.1161 - val_loss: 0.0256 - val_mae: 0.1225
# Epoch 239/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0245 - mae: 0.1157 - val_loss: 0.0253 - val_mae: 0.1219
# Epoch 240/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0242 - mae: 0.1152 - val_loss: 0.0249 - val_mae: 0.1212
# Epoch 241/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0240 - mae: 0.1147 - val_loss: 0.0246 - val_mae: 0.1206
# Epoch 242/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0238 - mae: 0.1142 - val_loss: 0.0243 - val_mae: 0.1200
# Epoch 243/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0235 - mae: 0.1137 - val_loss: 0.0240 - val_mae: 0.1194
# Epoch 244/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0233 - mae: 0.1133 - val_loss: 0.0236 - val_mae: 0.1188
# Epoch 245/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0230 - mae: 0.1128 - val_loss: 0.0234 - val_mae: 0.1182
# Epoch 246/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0228 - mae: 0.1124 - val_loss: 0.0231 - val_mae: 0.1177
# Epoch 247/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0226 - mae: 0.1119 - val_loss: 0.0228 - val_mae: 0.1172
# Epoch 248/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0224 - mae: 0.1116 - val_loss: 0.0225 - val_mae: 0.1166
# Epoch 249/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0222 - mae: 0.1112 - val_loss: 0.0222 - val_mae: 0.1160
# Epoch 250/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0219 - mae: 0.1108 - val_loss: 0.0220 - val_mae: 0.1154
# Epoch 251/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0217 - mae: 0.1103 - val_loss: 0.0217 - val_mae: 0.1148
# Epoch 252/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0215 - mae: 0.1099 - val_loss: 0.0215 - val_mae: 0.1141
# Epoch 253/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0213 - mae: 0.1094 - val_loss: 0.0212 - val_mae: 0.1135
# Epoch 254/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0211 - mae: 0.1090 - val_loss: 0.0210 - val_mae: 0.1129
# Epoch 255/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0209 - mae: 0.1086 - val_loss: 0.0207 - val_mae: 0.1124
# Epoch 256/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0207 - mae: 0.1082 - val_loss: 0.0205 - val_mae: 0.1119
# Epoch 257/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0205 - mae: 0.1077 - val_loss: 0.0202 - val_mae: 0.1114
# Epoch 258/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0203 - mae: 0.1074 - val_loss: 0.0200 - val_mae: 0.1109
# Epoch 259/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0201 - mae: 0.1069 - val_loss: 0.0198 - val_mae: 0.1103
# Epoch 260/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0199 - mae: 0.1065 - val_loss: 0.0196 - val_mae: 0.1098
# Epoch 261/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0197 - mae: 0.1062 - val_loss: 0.0194 - val_mae: 0.1093
# Epoch 262/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0195 - mae: 0.1058 - val_loss: 0.0191 - val_mae: 0.1088
# Epoch 263/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0194 - mae: 0.1055 - val_loss: 0.0189 - val_mae: 0.1083
# Epoch 264/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0192 - mae: 0.1051 - val_loss: 0.0187 - val_mae: 0.1078
# Epoch 265/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0190 - mae: 0.1048 - val_loss: 0.0185 - val_mae: 0.1073
# Epoch 266/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0188 - mae: 0.1045 - val_loss: 0.0183 - val_mae: 0.1068
# Epoch 267/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0187 - mae: 0.1042 - val_loss: 0.0181 - val_mae: 0.1063
# Epoch 268/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0185 - mae: 0.1038 - val_loss: 0.0179 - val_mae: 0.1058
# Epoch 269/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0184 - mae: 0.1035 - val_loss: 0.0177 - val_mae: 0.1054
# Epoch 270/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0182 - mae: 0.1032 - val_loss: 0.0176 - val_mae: 0.1049
# Epoch 271/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0181 - mae: 0.1029 - val_loss: 0.0174 - val_mae: 0.1044
# Epoch 272/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0179 - mae: 0.1026 - val_loss: 0.0172 - val_mae: 0.1040
# Epoch 273/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0178 - mae: 0.1023 - val_loss: 0.0170 - val_mae: 0.1036
# Epoch 274/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0176 - mae: 0.1020 - val_loss: 0.0169 - val_mae: 0.1031
# Epoch 275/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0175 - mae: 0.1018 - val_loss: 0.0167 - val_mae: 0.1026
# Epoch 276/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0173 - mae: 0.1014 - val_loss: 0.0165 - val_mae: 0.1022
# Epoch 277/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0172 - mae: 0.1012 - val_loss: 0.0164 - val_mae: 0.1018
# Epoch 278/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0171 - mae: 0.1008 - val_loss: 0.0162 - val_mae: 0.1014
# Epoch 279/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0170 - mae: 0.1006 - val_loss: 0.0161 - val_mae: 0.1010
# Epoch 280/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0168 - mae: 0.1002 - val_loss: 0.0160 - val_mae: 0.1006
# Epoch 281/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0167 - mae: 0.1000 - val_loss: 0.0159 - val_mae: 0.1002
# Epoch 282/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0166 - mae: 0.0997 - val_loss: 0.0157 - val_mae: 0.0998
# Epoch 283/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0165 - mae: 0.0995 - val_loss: 0.0156 - val_mae: 0.0994
# Epoch 284/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0163 - mae: 0.0991 - val_loss: 0.0155 - val_mae: 0.0990
# Epoch 285/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0162 - mae: 0.0989 - val_loss: 0.0153 - val_mae: 0.0987
# Epoch 286/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0161 - mae: 0.0986 - val_loss: 0.0152 - val_mae: 0.0984
# Epoch 287/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0160 - mae: 0.0984 - val_loss: 0.0151 - val_mae: 0.0980
# Epoch 288/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0159 - mae: 0.0981 - val_loss: 0.0150 - val_mae: 0.0977
# Epoch 289/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0158 - mae: 0.0978 - val_loss: 0.0149 - val_mae: 0.0974
# Epoch 290/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0157 - mae: 0.0976 - val_loss: 0.0148 - val_mae: 0.0971
# Epoch 291/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0156 - mae: 0.0974 - val_loss: 0.0147 - val_mae: 0.0967
# Epoch 292/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0155 - mae: 0.0972 - val_loss: 0.0146 - val_mae: 0.0964
# Epoch 293/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0154 - mae: 0.0969 - val_loss: 0.0145 - val_mae: 0.0960
# Epoch 294/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0153 - mae: 0.0967 - val_loss: 0.0144 - val_mae: 0.0957
# Epoch 295/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0152 - mae: 0.0965 - val_loss: 0.0142 - val_mae: 0.0954
# Epoch 296/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0151 - mae: 0.0964 - val_loss: 0.0141 - val_mae: 0.0950
# Epoch 297/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0150 - mae: 0.0961 - val_loss: 0.0140 - val_mae: 0.0947
# Epoch 298/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0150 - mae: 0.0959 - val_loss: 0.0140 - val_mae: 0.0944
# Epoch 299/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0149 - mae: 0.0957 - val_loss: 0.0139 - val_mae: 0.0942
# Epoch 300/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0148 - mae: 0.0956 - val_loss: 0.0138 - val_mae: 0.0939
# Epoch 301/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0147 - mae: 0.0954 - val_loss: 0.0137 - val_mae: 0.0936
# Epoch 302/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0146 - mae: 0.0952 - val_loss: 0.0137 - val_mae: 0.0934
# Epoch 303/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0146 - mae: 0.0950 - val_loss: 0.0136 - val_mae: 0.0931
# Epoch 304/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0145 - mae: 0.0949 - val_loss: 0.0135 - val_mae: 0.0928
# Epoch 305/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0144 - mae: 0.0948 - val_loss: 0.0135 - val_mae: 0.0926
# Epoch 306/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0144 - mae: 0.0946 - val_loss: 0.0134 - val_mae: 0.0924
# Epoch 307/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0143 - mae: 0.0944 - val_loss: 0.0133 - val_mae: 0.0921
# Epoch 308/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0142 - mae: 0.0943 - val_loss: 0.0133 - val_mae: 0.0919
# Epoch 309/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0142 - mae: 0.0942 - val_loss: 0.0132 - val_mae: 0.0917
# Epoch 310/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0141 - mae: 0.0941 - val_loss: 0.0131 - val_mae: 0.0914
# Epoch 311/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0141 - mae: 0.0938 - val_loss: 0.0130 - val_mae: 0.0912
# Epoch 312/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0140 - mae: 0.0936 - val_loss: 0.0130 - val_mae: 0.0911
# Epoch 313/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0139 - mae: 0.0935 - val_loss: 0.0129 - val_mae: 0.0908
# Epoch 314/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0139 - mae: 0.0934 - val_loss: 0.0129 - val_mae: 0.0907
# Epoch 315/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0138 - mae: 0.0934 - val_loss: 0.0128 - val_mae: 0.0906
# Epoch 316/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0138 - mae: 0.0933 - val_loss: 0.0128 - val_mae: 0.0902
# Epoch 317/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0137 - mae: 0.0931 - val_loss: 0.0127 - val_mae: 0.0900
# Epoch 318/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0136 - mae: 0.0930 - val_loss: 0.0127 - val_mae: 0.0900
# Epoch 319/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0136 - mae: 0.0929 - val_loss: 0.0126 - val_mae: 0.0895
# Epoch 320/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0135 - mae: 0.0926 - val_loss: 0.0125 - val_mae: 0.0894
# Epoch 321/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0135 - mae: 0.0926 - val_loss: 0.0125 - val_mae: 0.0893
# Epoch 322/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0134 - mae: 0.0924 - val_loss: 0.0125 - val_mae: 0.0891
# Epoch 323/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0134 - mae: 0.0924 - val_loss: 0.0124 - val_mae: 0.0889
# Epoch 324/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0133 - mae: 0.0922 - val_loss: 0.0124 - val_mae: 0.0888
# Epoch 325/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0133 - mae: 0.0921 - val_loss: 0.0123 - val_mae: 0.0886
# Epoch 326/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0133 - mae: 0.0920 - val_loss: 0.0123 - val_mae: 0.0884
# Epoch 327/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0132 - mae: 0.0919 - val_loss: 0.0123 - val_mae: 0.0883
# Epoch 328/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0132 - mae: 0.0918 - val_loss: 0.0122 - val_mae: 0.0882
# Epoch 329/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0132 - mae: 0.0917 - val_loss: 0.0122 - val_mae: 0.0880
# Epoch 330/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0131 - mae: 0.0916 - val_loss: 0.0121 - val_mae: 0.0878
# Epoch 331/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0131 - mae: 0.0914 - val_loss: 0.0121 - val_mae: 0.0879
# Epoch 332/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0131 - mae: 0.0915 - val_loss: 0.0121 - val_mae: 0.0876
# Epoch 333/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0130 - mae: 0.0913 - val_loss: 0.0120 - val_mae: 0.0874
# Epoch 334/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0129 - mae: 0.0911 - val_loss: 0.0120 - val_mae: 0.0875
# Epoch 335/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0129 - mae: 0.0912 - val_loss: 0.0120 - val_mae: 0.0873
# Epoch 336/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0129 - mae: 0.0910 - val_loss: 0.0119 - val_mae: 0.0870
# Epoch 337/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0128 - mae: 0.0909 - val_loss: 0.0119 - val_mae: 0.0872
# Epoch 338/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0128 - mae: 0.0910 - val_loss: 0.0119 - val_mae: 0.0869
# Epoch 339/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0128 - mae: 0.0908 - val_loss: 0.0119 - val_mae: 0.0867
# Epoch 340/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0128 - mae: 0.0906 - val_loss: 0.0118 - val_mae: 0.0868
# Epoch 341/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0128 - mae: 0.0907 - val_loss: 0.0118 - val_mae: 0.0866
# Epoch 342/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0127 - mae: 0.0905 - val_loss: 0.0118 - val_mae: 0.0864
# Epoch 343/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0127 - mae: 0.0904 - val_loss: 0.0118 - val_mae: 0.0866
# Epoch 344/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0127 - mae: 0.0905 - val_loss: 0.0117 - val_mae: 0.0863
# Epoch 345/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0127 - mae: 0.0903 - val_loss: 0.0117 - val_mae: 0.0861
# Epoch 346/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0126 - mae: 0.0902 - val_loss: 0.0117 - val_mae: 0.0863
# Epoch 347/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0126 - mae: 0.0903 - val_loss: 0.0116 - val_mae: 0.0861
# Epoch 348/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0126 - mae: 0.0901 - val_loss: 0.0116 - val_mae: 0.0860
# Epoch 349/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0126 - mae: 0.0901 - val_loss: 0.0116 - val_mae: 0.0859
# Epoch 350/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0125 - mae: 0.0899 - val_loss: 0.0116 - val_mae: 0.0859
# Epoch 351/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0125 - mae: 0.0899 - val_loss: 0.0116 - val_mae: 0.0860
# Epoch 352/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0125 - mae: 0.0900 - val_loss: 0.0116 - val_mae: 0.0859
# Epoch 353/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0125 - mae: 0.0900 - val_loss: 0.0115 - val_mae: 0.0857
# Epoch 354/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0125 - mae: 0.0897 - val_loss: 0.0115 - val_mae: 0.0856
# Epoch 355/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0124 - mae: 0.0897 - val_loss: 0.0115 - val_mae: 0.0856
# Epoch 356/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0125 - mae: 0.0897 - val_loss: 0.0115 - val_mae: 0.0855
# Epoch 357/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0124 - mae: 0.0897 - val_loss: 0.0115 - val_mae: 0.0854
# Epoch 358/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0124 - mae: 0.0896 - val_loss: 0.0114 - val_mae: 0.0853
# Epoch 359/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0124 - mae: 0.0896 - val_loss: 0.0114 - val_mae: 0.0853
# Epoch 360/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0124 - mae: 0.0895 - val_loss: 0.0114 - val_mae: 0.0852
# Epoch 361/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0124 - mae: 0.0895 - val_loss: 0.0114 - val_mae: 0.0853
# Epoch 362/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0124 - mae: 0.0896 - val_loss: 0.0114 - val_mae: 0.0852
# Epoch 363/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0124 - mae: 0.0895 - val_loss: 0.0113 - val_mae: 0.0851
# Epoch 364/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0123 - mae: 0.0894 - val_loss: 0.0113 - val_mae: 0.0850
# Epoch 365/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0123 - mae: 0.0893 - val_loss: 0.0113 - val_mae: 0.0849
# Epoch 366/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0123 - mae: 0.0893 - val_loss: 0.0113 - val_mae: 0.0849
# Epoch 367/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0123 - mae: 0.0892 - val_loss: 0.0113 - val_mae: 0.0849
# Epoch 368/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0123 - mae: 0.0893 - val_loss: 0.0113 - val_mae: 0.0848
# Epoch 369/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0123 - mae: 0.0891 - val_loss: 0.0113 - val_mae: 0.0848
# Epoch 370/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0123 - mae: 0.0891 - val_loss: 0.0113 - val_mae: 0.0848
# Epoch 371/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0123 - mae: 0.0891 - val_loss: 0.0112 - val_mae: 0.0847
# Epoch 372/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122 - mae: 0.0890 - val_loss: 0.0112 - val_mae: 0.0847
# Epoch 373/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122 - mae: 0.0890 - val_loss: 0.0113 - val_mae: 0.0849
# Epoch 374/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122 - mae: 0.0891 - val_loss: 0.0112 - val_mae: 0.0847
# Epoch 375/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122 - mae: 0.0890 - val_loss: 0.0112 - val_mae: 0.0845
# Epoch 376/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122 - mae: 0.0888 - val_loss: 0.0112 - val_mae: 0.0845
# Epoch 377/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122 - mae: 0.0888 - val_loss: 0.0112 - val_mae: 0.0847
# Epoch 378/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122 - mae: 0.0888 - val_loss: 0.0112 - val_mae: 0.0847
# Epoch 379/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122 - mae: 0.0888 - val_loss: 0.0112 - val_mae: 0.0848
# Epoch 380/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0121 - mae: 0.0887 - val_loss: 0.0112 - val_mae: 0.0847
# Epoch 381/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0121 - mae: 0.0885 - val_loss: 0.0113 - val_mae: 0.0849
# Epoch 382/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0121 - mae: 0.0885 - val_loss: 0.0113 - val_mae: 0.0851
# Epoch 383/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0121 - mae: 0.0885 - val_loss: 0.0113 - val_mae: 0.0851
# Epoch 384/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0121 - mae: 0.0885 - val_loss: 0.0113 - val_mae: 0.0849
# Epoch 385/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0121 - mae: 0.0884 - val_loss: 0.0113 - val_mae: 0.0850
# Epoch 386/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0121 - mae: 0.0884 - val_loss: 0.0112 - val_mae: 0.0849
# Epoch 387/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0121 - mae: 0.0883 - val_loss: 0.0112 - val_mae: 0.0850
# Epoch 388/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0121 - mae: 0.0883 - val_loss: 0.0113 - val_mae: 0.0851
# Epoch 389/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0121 - mae: 0.0884 - val_loss: 0.0112 - val_mae: 0.0850
# Epoch 390/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - mae: 0.0883 - val_loss: 0.0112 - val_mae: 0.0849
# Epoch 391/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - mae: 0.0882 - val_loss: 0.0112 - val_mae: 0.0849
# Epoch 392/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - mae: 0.0882 - val_loss: 0.0112 - val_mae: 0.0851
# Epoch 393/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - mae: 0.0883 - val_loss: 0.0112 - val_mae: 0.0850
# Epoch 394/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - mae: 0.0883 - val_loss: 0.0112 - val_mae: 0.0849
# Epoch 395/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - mae: 0.0881 - val_loss: 0.0112 - val_mae: 0.0849
# Epoch 396/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - mae: 0.0881 - val_loss: 0.0112 - val_mae: 0.0848
# Epoch 397/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - mae: 0.0881 - val_loss: 0.0112 - val_mae: 0.0849
# Epoch 398/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - mae: 0.0881 - val_loss: 0.0112 - val_mae: 0.0848
# Epoch 399/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0120 - mae: 0.0880 - val_loss: 0.0112 - val_mae: 0.0848
# Epoch 400/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - mae: 0.0880 - val_loss: 0.0112 - val_mae: 0.0848
# Epoch 401/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - mae: 0.0880 - val_loss: 0.0112 - val_mae: 0.0847
# Epoch 402/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - mae: 0.0879 - val_loss: 0.0112 - val_mae: 0.0848
# Epoch 403/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - mae: 0.0879 - val_loss: 0.0112 - val_mae: 0.0848
# Epoch 404/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - mae: 0.0879 - val_loss: 0.0112 - val_mae: 0.0848
# Epoch 405/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - mae: 0.0880 - val_loss: 0.0112 - val_mae: 0.0848
# Epoch 406/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120 - mae: 0.0880 - val_loss: 0.0111 - val_mae: 0.0847
# Epoch 407/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0879 - val_loss: 0.0111 - val_mae: 0.0846
# Epoch 408/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0878 - val_loss: 0.0111 - val_mae: 0.0847
# Epoch 409/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0878 - val_loss: 0.0111 - val_mae: 0.0847
# Epoch 410/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0878 - val_loss: 0.0111 - val_mae: 0.0848
# Epoch 411/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0879 - val_loss: 0.0111 - val_mae: 0.0848
# Epoch 412/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0119 - mae: 0.0879 - val_loss: 0.0111 - val_mae: 0.0846
# Epoch 413/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0878 - val_loss: 0.0111 - val_mae: 0.0846
# Epoch 414/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0877 - val_loss: 0.0111 - val_mae: 0.0845
# Epoch 415/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0877 - val_loss: 0.0111 - val_mae: 0.0846
# Epoch 416/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0877 - val_loss: 0.0111 - val_mae: 0.0846
# Epoch 417/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0877 - val_loss: 0.0111 - val_mae: 0.0848
# Epoch 418/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0877 - val_loss: 0.0111 - val_mae: 0.0847
# Epoch 419/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0877 - val_loss: 0.0111 - val_mae: 0.0846
# Epoch 420/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0877 - val_loss: 0.0111 - val_mae: 0.0846
# Epoch 421/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0119 - mae: 0.0876 - val_loss: 0.0111 - val_mae: 0.0846
# Epoch 422/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0876 - val_loss: 0.0111 - val_mae: 0.0846
# Epoch 423/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0876 - val_loss: 0.0111 - val_mae: 0.0846
# Epoch 424/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0876 - val_loss: 0.0111 - val_mae: 0.0846
# Epoch 425/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0875 - val_loss: 0.0111 - val_mae: 0.0848
# Epoch 426/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0876 - val_loss: 0.0111 - val_mae: 0.0847
# Epoch 427/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0876 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 428/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0876 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 429/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0875 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 430/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0874 - val_loss: 0.0111 - val_mae: 0.0847
# Epoch 431/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0875 - val_loss: 0.0111 - val_mae: 0.0847
# Epoch 432/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0876 - val_loss: 0.0110 - val_mae: 0.0847
# Epoch 433/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0875 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 434/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0119 - mae: 0.0875 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 435/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0875 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 436/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0875 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 437/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0875 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 438/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0874 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 439/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0874 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 440/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0874 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 441/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0874 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 442/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0874 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 443/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0119 - mae: 0.0874 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 444/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0874 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 445/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0874 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 446/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0873 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 447/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0873 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 448/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0873 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 449/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0873 - val_loss: 0.0110 - val_mae: 0.0845
# Epoch 450/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0873 - val_loss: 0.0110 - val_mae: 0.0845
# Epoch 451/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0873 - val_loss: 0.0110 - val_mae: 0.0845
# Epoch 452/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0873 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 453/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0873 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 454/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0873 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 455/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0873 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 456/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0873 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 457/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0873 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 458/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0873 - val_loss: 0.0110 - val_mae: 0.0845
# Epoch 459/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0873 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 460/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0873 - val_loss: 0.0110 - val_mae: 0.0845
# Epoch 461/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 462/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0110 - val_mae: 0.0845
# Epoch 463/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 464/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0110 - val_mae: 0.0845
# Epoch 465/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0110 - val_mae: 0.0845
# Epoch 466/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0110 - val_mae: 0.0845
# Epoch 467/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 468/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0110 - val_mae: 0.0845
# Epoch 469/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 470/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 471/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 472/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0110 - val_mae: 0.0845
# Epoch 473/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 474/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 475/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0109 - val_mae: 0.0846
# Epoch 476/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0109 - val_mae: 0.0846
# Epoch 477/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 478/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0110 - val_mae: 0.0846
# Epoch 479/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0109 - val_mae: 0.0846
# Epoch 480/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0109 - val_mae: 0.0845
# Epoch 481/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0845
# Epoch 482/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0845
# Epoch 483/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0845
# Epoch 484/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0846
# Epoch 485/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0109 - val_mae: 0.0845
# Epoch 486/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0846
# Epoch 487/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0872 - val_loss: 0.0109 - val_mae: 0.0845
# Epoch 488/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0846
# Epoch 489/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0845
# Epoch 490/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0846
# Epoch 491/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0845
# Epoch 492/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0846
# Epoch 493/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0845
# Epoch 494/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0846
# Epoch 495/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0844
# Epoch 496/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0845
# Epoch 497/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0845
# Epoch 498/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0845
# Epoch 499/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0846
# Epoch 500/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0109 - val_mae: 0.0846

# %% [markdown]
# ### Plot Metrics
# Each training epoch, the model prints out its loss and mean absolute error for training and validation. You can read this in the output above (note that your exact numbers may differ):
#
# ```
# Epoch 500/500
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0121 - mae: 0.0882 - val_loss: 0.0115 - val_mae: 0.0865
# ```
#
# You can see that we've already got a huge improvement - validation loss has dropped from 0.15 to 0.01, and validation MAE has dropped from 0.33 to 0.08.
#
# The following cell will print the same graphs we used to evaluate our original model, but showing our new training history:

# %%
# Draw a graph of the loss, which is the distance between
# the predicted and actual values during training and validation.
train_loss = history_large.history['loss']
val_loss = history_large.history['val_loss']

epochs = range(1, len(train_loss) + 1)

# Exclude the first few epochs so the graph is easier to read
SKIP = 100

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)

plt.plot(epochs[SKIP:], train_loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)

# Draw a graph of mean absolute error, which is another way of
# measuring the amount of error in the prediction.
train_mae = history_large.history['mae']
val_mae = history_large.history['val_mae']

plt.plot(epochs[SKIP:], train_mae[SKIP:], 'g.', label='Training MAE')
plt.plot(epochs[SKIP:], val_mae[SKIP:], 'b.', label='Validation MAE')
plt.title('Training and validation mean absolute error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()

plt.tight_layout()

# %% [markdown]
# Great results! From these graphs, we can see several exciting things:
#
# *   The overall loss and MAE are much better than our previous network
# *   Metrics are better for validation than training, which means the network is not overfitting
#
# The reason the metrics for validation are better than those for training is that validation metrics are calculated at the end of each epoch, while training metrics are calculated throughout the epoch, so validation happens on a model that has been trained slightly longer.
#
# This all means our network seems to be performing well! To confirm, let's check its predictions against the test dataset we set aside earlier:

# %%
# Calculate and print the loss on our test dataset
test_loss, test_mae = model_large.evaluate(x_test, y_test)

# Make predictions based on our test dataset
y_test_pred = model_large.predict(x_test)

# Graph the predictions against the actual values
plt.clf()
plt.title('Comparison of predictions and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual values')
plt.plot(x_test, y_test_pred, 'r.', label='TF predicted')
plt.legend()
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0106 - mae: 0.0830
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# Much better! The evaluation metrics we printed show that the model has a low loss and MAE on the test data, and the predictions line up visually with our data fairly well.
#
# The model isn't perfect; its predictions don't form a smooth sine curve. For instance, the line is almost straight when `x` is between 4.2 and 5.2. If we wanted to go further, we could try further increasing the capacity of the model, perhaps using some techniques to defend from overfitting.

# %% [markdown]
# ### Generate Models with and without Quantization
# We now have an acceptably accurate model. We'll use the [TensorFlow Lite Converter](https://www.tensorflow.org/lite/convert) to convert the model into a special, space-efficient format for use on memory-constrained devices.
#
# Since this model is going to be deployed on a microcontroller, we want it to be as tiny as possible! One technique for reducing the size of a model is called [quantization](https://www.tensorflow.org/lite/performance/post_training_quantization). It reduces the precision of the model's weights, and possibly the activations (output of each layer) as well, which saves memory, often without much impact on accuracy. Quantized models also run faster, since the calculations required are simpler.
#
# In the following cell, we'll convert the model twice: once with quantization, once without.

# %% [markdown]
# #### Convert the model to the TensorFlow Lite format without quantization

# %%
# Convert to float TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model_large)
model_no_quant_tflite = converter.convert()

# Save the model to disk
with open(MODEL_NO_QUANT_TFLITE, "wb") as f:
    f.write(model_no_quant_tflite)
# Out:
# INFO:tensorflow:Assets written to: /var/folders/l4/w09y24z95s7gv9qb_3347lsm0000gn/T/tmplfazeef_/assets
# INFO:tensorflow:Assets written to: /var/folders/l4/w09y24z95s7gv9qb_3347lsm0000gn/T/tmplfazeef_/assets
# Saved artifact at '/var/folders/l4/w09y24z95s7gv9qb_3347lsm0000gn/T/tmplfazeef_'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 1), dtype=tf.float32, name='keras_tensor_3')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   12914176080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12914174544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12914175888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12914171472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12914175312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12914173200: TensorSpec(shape=(), dtype=tf.resource, name=None)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1742815761.285597 2615154 tf_tfl_flatbuffer_helpers.cc:392] Ignored output_format.
# W0000 00:00:1742815761.285646 2615154 tf_tfl_flatbuffer_helpers.cc:395] Ignored drop_control_dependency.
# 2025-03-24 12:29:21.285890: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /var/folders/l4/w09y24z95s7gv9qb_3347lsm0000gn/T/tmplfazeef_
# 2025-03-24 12:29:21.286244: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-03-24 12:29:21.286249: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /var/folders/l4/w09y24z95s7gv9qb_3347lsm0000gn/T/tmplfazeef_
# 2025-03-24 12:29:21.288945: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# 2025-03-24 12:29:21.289416: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-03-24 12:29:21.306265: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /var/folders/l4/w09y24z95s7gv9qb_3347lsm0000gn/T/tmplfazeef_
# 2025-03-24 12:29:21.311505: I tensorflow/cc/saved_model/loader.cc:462] SavedModel load for tags { serve }; Status: success: OK. Took 25616 microseconds.
# 2025-03-24 12:29:21.319179: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.

# %% [markdown]
# #### Convert the model to the TensorFlow Lite format with quantization

# %%
def representative_dataset():
  for i in range(500):
    yield([x_train[i].reshape(1, 1)])

# Set the optimization flag.
converter = tf.lite.TFLiteConverter.from_keras_model(model_large)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# Enforce integer only quantization
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
# Provide a representative dataset to ensure we quantize correctly.
converter.representative_dataset = representative_dataset
model_int8_quant_tflite = converter.convert()

# Save the model to disk
with open(MODEL_INT8_QUANT_TFLITE, "wb") as f:
    f.write(model_int8_quant_tflite)
# Out:
# INFO:tensorflow:Assets written to: /var/folders/l4/w09y24z95s7gv9qb_3347lsm0000gn/T/tmpfdkjtzw8/assets
# INFO:tensorflow:Assets written to: /var/folders/l4/w09y24z95s7gv9qb_3347lsm0000gn/T/tmpfdkjtzw8/assets
# Saved artifact at '/var/folders/l4/w09y24z95s7gv9qb_3347lsm0000gn/T/tmpfdkjtzw8'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 1), dtype=tf.float32, name='keras_tensor_3')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   12914176080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12914174544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12914175888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12914171472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12914175312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12914173200: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:983: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1742815761.517308 2615154 tf_tfl_flatbuffer_helpers.cc:392] Ignored output_format.
# W0000 00:00:1742815761.517318 2615154 tf_tfl_flatbuffer_helpers.cc:395] Ignored drop_control_dependency.
# 2025-03-24 12:29:21.517455: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /var/folders/l4/w09y24z95s7gv9qb_3347lsm0000gn/T/tmpfdkjtzw8
# 2025-03-24 12:29:21.517802: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-03-24 12:29:21.517807: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /var/folders/l4/w09y24z95s7gv9qb_3347lsm0000gn/T/tmpfdkjtzw8
# 2025-03-24 12:29:21.520764: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-03-24 12:29:21.538720: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /var/folders/l4/w09y24z95s7gv9qb_3347lsm0000gn/T/tmpfdkjtzw8
# 2025-03-24 12:29:21.544061: I tensorflow/cc/saved_model/loader.cc:462] SavedModel load for tags { serve }; Status: success: OK. Took 26606 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8

# %% [markdown]
# ### Compare Model Performance
#
# To prove these models are accurate even after conversion and quantization, we'll compare their predictions and loss on our test dataset.
#
# #### Helper functions
#
# This code defines two functions for working with TensorFlow Lite (TFLite) models: **predict_tflite** and **evaluate_tflite**.
#
# - The predict_tflite function takes a TFLite model and test data, prepares the input, runs inference using the TFLite interpreter, and handles any necessary quantization or dequantization of inputs and outputs.
#
# - The evaluate_tflite function uses predict_tflite to generate predictions and then calculates the loss using the original model's loss function. These functions allow for efficient inference and evaluation of TFLite models, which are optimized versions of TensorFlow models designed for deployment on resource-constrained devices.

# %%
def predict_tflite(tflite_model, x_test):
  # Prepare the test data
  x_test_ = x_test.copy()
  x_test_ = x_test_.reshape((x_test.size, 1))
  x_test_ = x_test_.astype(np.float32)

  # Initialize the TFLite interpreter
  interpreter = tf.lite.Interpreter(model_content=tflite_model)
  interpreter.allocate_tensors()

  input_details = interpreter.get_input_details()[0]
  output_details = interpreter.get_output_details()[0]

  # If required, quantize the input layer (from float to integer)
  input_scale, input_zero_point = input_details["quantization"]
  if (input_scale, input_zero_point) != (0.0, 0):
    x_test_ = x_test_ / input_scale + input_zero_point
    x_test_ = x_test_.astype(input_details["dtype"])

  # Invoke the interpreter
  y_pred = np.empty(x_test_.size, dtype=output_details["dtype"])
  for i in range(len(x_test_)):
    interpreter.set_tensor(input_details["index"], [x_test_[i]])
    interpreter.invoke()
    y_pred[i] = interpreter.get_tensor(output_details["index"])[0]

  # If required, dequantized the output layer (from integer to float)
  output_scale, output_zero_point = output_details["quantization"]
  if (output_scale, output_zero_point) != (0.0, 0):
    y_pred = y_pred.astype(np.float32)
    y_pred = (y_pred - output_zero_point) * output_scale

  return y_pred

def evaluate_tflite(tflite_model, x_test, y_true):
  global model
  y_pred = predict_tflite(tflite_model, x_test)
  loss_function = keras.losses.get(model_large.loss)
  loss = loss_function(y_true, y_pred).numpy()
  return loss

# %% [markdown]
# #### Predictions
#
# Use the helper functions:

# %%
# Calculate predictions
y_test_pred_tf = model_large.predict(x_test)
y_test_pred_no_quant_tflite = predict_tflite(model_no_quant_tflite, x_test)
y_test_pred_int8_quant_tflite = predict_tflite(model_int8_quant_tflite, x_test)

# Compare predictions
plt.clf()
plt.title('Comparison of various models against actual values')
plt.plot(x_test, y_test, 'bo', label='Actual values')
plt.plot(x_test, y_test_pred_tf, 'ro', label='TF predictions')
plt.plot(x_test, y_test_pred_no_quant_tflite, 'bx', label='TFLite predictions')
plt.plot(x_test, y_test_pred_int8_quant_tflite, 'gx', label='TFLite quantized predictions')
plt.legend()
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# INFO: /var/folders/l4/w09y24z95s7gv9qb_3347lsm0000gn/T/ipykernel_25291/2557248112.py:25: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_pred[i] = interpreter.get_tensor(output_details["index"])[0]
# Created TensorFlow Lite XNNPACK delegate for CPU.

# %% [markdown]
# #### Loss (MSE/Mean Squared Error)
#
# Mean Squared Error (MSE) is a widely used loss function in machine learning, particularly for regression tasks. It measures the average of the squared differences between predicted and actual value.
#
# The formula is:
# $$
# MSE = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y_i})^2
# $$
#
# We can retrieve these values from the Keras framework.

# %%
# Calculate loss
loss_tf, _ = model_large.evaluate(x_test, y_test, verbose=0)
loss_no_quant_tflite = evaluate_tflite(model_no_quant_tflite, x_test, y_test)
loss_int8_quant_tflite = evaluate_tflite(model_int8_quant_tflite, x_test, y_test)

# Compare loss
import pandas as pd

df = pd.DataFrame.from_records(
    [["TensorFlow / Keras", loss_tf],
     ["TensorFlow Lite", loss_no_quant_tflite],
     ["TensorFlow Lite Quantized", loss_int8_quant_tflite]],
     columns = ["Model", "Loss/MSE"], index="Model").round(4)
df
# Out:
# /var/folders/l4/w09y24z95s7gv9qb_3347lsm0000gn/T/ipykernel_25291/2557248112.py:25: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_pred[i] = interpreter.get_tensor(output_details["index"])[0]
#                            Loss/MSE
# Model
# TensorFlow / Keras           0.0099
# TensorFlow Lite              0.0099
# TensorFlow Lite Quantized    0.0103

# %% [markdown]
# #### Size
#
# Get the size of the binary files.

# %%
# Calculate size
size_tf = os.path.getsize(MODEL_KERAS)
size_no_quant_tflite = os.path.getsize(MODEL_NO_QUANT_TFLITE)
size_int8_quant_tflite = os.path.getsize(MODEL_INT8_QUANT_TFLITE)

# Compare size
pd.DataFrame.from_records(
    [["TensorFlow / Keras", f"{size_tf} bytes", ""],
     ["TensorFlow Lite", f"{size_no_quant_tflite} bytes ", f"(reduced by {size_tf - size_no_quant_tflite} bytes)"],
     ["TensorFlow Lite Quantized", f"{size_int8_quant_tflite} bytes", f"(reduced by {size_no_quant_tflite - size_int8_quant_tflite} bytes)"]],
     columns = ["Model", "Size", ""], index="Model")
# Out:
#                                   Size
# Model
# TensorFlow / Keras         29243 bytes
# TensorFlow Lite            3164 bytes   (reduced by 26079 bytes)
# TensorFlow Lite Quantized   3424 bytes   (reduced by -260 bytes)

# %% [markdown]
# ## Deploy model to the Firmware Project
# Convert the TensorFlow Lite quantized model into a C source file that can be loaded by TensorFlow Lite for Microcontrollers.

# %%
import os
import re

def sanitize_name(name):
    """Convert filename to valid C variable name."""
    return re.sub(r'[^a-zA-Z0-9]+', '_', name)

def convert_to_c_source(input_file, output_file, bytes_per_line=12):
    """Convert binary file to C source array."""
    var_name = sanitize_name(os.path.basename(input_file))
    
    with open(input_file, 'rb') as f_in:
        content = f_in.read()
    
    with open(output_file, 'w') as f_out:
        f_out.write(f"const unsigned char {var_name}[] = {{\n  ")
        
        # Write bytes in hex format
        for i, byte in enumerate(content):
            if i > 0 and i % bytes_per_line == 0:
                f_out.write("\n  ")
            f_out.write(f"0x{byte:02x}, ")
        
        f_out.write(f"\n}};\n")
        f_out.write(f"const unsigned int {var_name}_len = {len(content)};\n")


convert_to_c_source(MODEL_NO_QUANT_TFLITE, MODEL_NO_QUANT_C)
convert_to_c_source(MODEL_INT8_QUANT_TFLITE, MODEL_INT8_QUANT_C)

# %% [markdown]
# ## Convert to Ethos-U NPU model
#
# Optionally convert the model for targets featuring the Ethos-U NPU.

# %%
import site

# Get the site-packages path to find vela
site_packages_path = site.getsitepackages()[0]
print(site_packages_path)

# Construct the installation path of vela
velapath = os.path.join(os.path.dirname(os.path.dirname(os.path.dirname(site_packages_path))), 'bin/vela')

# Convert the model to a Vela model
# !{velapath} models/model_int8.tflite --output-dir models_vela   --verbose-operators

convert_to_c_source ("models_vela/model_int8_vela.tflite", "models_vela/model_int8_vela.c")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages
# Warning: No configuration file specified. Using a default of ['/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ethosu/config_files/Arm/vela.ini']. Compilation may be invalid or non-optimal.
# Warning: No system configuration specified. Using a default of Ethos_U55_High_End_Embedded. Compilation may be invalid or non-optimal.
# Warning: No memory mode specified. Using a default of Shared_Sram. Compilation may be invalid or non-optimal.
# Operators of Subgraph main
#   0: FullyConnected - {'attribute_read_error': [], 'asymmetric_quantize_inputs': False, 'fused_activation_function': Relu, 'keep_num_dims': False, 'weights_format': 0, 'quantized_bias_type': 0} - sequential_1_1/dense_2_1/MatMul;sequential_1_1/dense_2_1/Relu;sequential_1_1/dense_2_1/BiasAdd
#   1: FullyConnected - {'attribute_read_error': [], 'asymmetric_quantize_inputs': False, 'fused_activation_function': Relu, 'keep_num_dims': False, 'weights_format': 0, 'quantized_bias_type': 0} - sequential_1_1/dense_3_1/MatMul;sequential_1_1/dense_3_1/Relu;sequential_1_1/dense_3_1/BiasAdd
#   2: FullyConnected - {'attribute_read_error': [], 'asymmetric_quantize_inputs': False, 'fused_activation_function': None, 'keep_num_dims': False, 'weights_format': 0, 'quantized_bias_type': 0} - StatefulPartitionedCall_1:0
#
# Network summary for model_int8
# Accelerator configuration               Ethos_U55_256
# System configuration             Ethos_U55_High_End_Embedded
# Memory mode                               Shared_Sram
# Accelerator clock                                 500 MHz
# Design peak SRAM bandwidth                       3.73 GB/s
# Design peak Off-chip Flash bandwidth             0.47 GB/s
#
# Total SRAM used                                  0.03 KiB
# Total Off-chip Flash used                        1.55 KiB
#
# CPU operators = 0 (0.0%)
# NPU operators = 3 (100.0%)
#
# Average SRAM bandwidth                           0.04 GB/s
# Input   SRAM bandwidth                           0.00 MB/batch
# Weight  SRAM bandwidth                           0.00 MB/batch
# Output  SRAM bandwidth                           0.00 MB/batch
# Total   SRAM bandwidth                           0.00 MB/batch
# Total   SRAM bandwidth            per input      0.00 MB/inference (batch size 1)
#
# Average Off-chip Flash bandwidth                 0.48 GB/s
# Input   Off-chip Flash bandwidth                 0.00 MB/batch
# Weight  Off-chip Flash bandwidth                 0.00 MB/batch
# Output  Off-chip Flash bandwidth                 0.00 MB/batch
# Total   Off-chip Flash bandwidth                 0.00 MB/batch
# Total   Off-chip Flash bandwidth  per input      0.00 MB/inference (batch size 1)
#
# Neural network macs                               288 MACs/batch

# %%
#Display the models_vela/model_int8_summary_Ethos_U55_High_End_Embedded.csv convertion metrics
df = pd.read_csv("models_vela/model_int8_summary_Ethos_U55_High_End_Embedded.csv")
df
# Out:
#   experiment     network accelerator_configuration  \
# 0    default  model_int8             Ethos_U55_256
#
#                  system_config  memory_mode   core_clock  arena_cache_size  \
# 0  Ethos_U55_High_End_Embedded  Shared_Sram  500000000.0         4194304.0
#
#    sram_bandwidth  dram_bandwidth  on_chip_flash_bandwidth  ...  \
# 0         3.72529         3.72529                  3.72529  ...
#
#    off_chip_flash_weight_write_bytes off_chip_flash_total_bytes nn_macs  \
# 0                                0.0                      752.0     288
#
#     nn_tops  cycles_npu  cycles_sram_access  cycles_dram_access  \
# 0  0.000383       272.0                 9.0                 0.0
#
#    cycles_on_chip_flash_access  cycles_off_chip_flash_access  cycles_total
# 0                          0.0                         752.0         752.0
#
# [1 rows x 52 columns]

# %% [markdown]
# ## Deploy to a Microcontroller
#
# Within this project, the model is copied into the Model layer in [`Model`] after the Jupyter Notebook executed successful. There is will be used by hello_world_test.cpp.

# %%
import shutil
# Copy model_int8.c to ../Model/ directory
shutil.copy('models/model_int8.c', '../Model/')

# Copy model_float.c to ../Model/ directory
shutil.copy('models/model_float.c', '../Model/')

# Copy model_int8_vela.c to ../Model/ directory
shutil.copy('models_vela/model_int8_vela.c', '../Model/')
# Out:
# '../Model/model_int8_vela.c'
